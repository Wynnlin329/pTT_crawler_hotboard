# %%
import requests
from bs4 import BeautifulSoup
import os
import time
import re
import pymysql
import pandas as pd

# %%
# !pip install pandas
# !pip install bs4
# !pip install pymysql
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting pandas
#   Downloading pandas-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 43 kB/s  eta 0:00:01
# Collecting pytz>=2017.2
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 588 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas) (2.8.1)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.18.1-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 39 kB/s  eta 0:00:01
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.18.1 pandas-1.0.1 pytz-2019.3

# %%
# 開啟資料庫連線
#db=pymysql.connect(host='mysql',user='root',passwd='123456',port=3306,charset='utf8')
db = pymysql.connect("mysql","root","123456","", )
cursor.execute("create database if not exists pttDB")
db = pymysql.connect("mysql","root","123456","pttDB",charset='utf8' )

# 使用 cursor() 方法建立一個遊標物件 cursor
cursor = db.cursor()
# 使用 execute()  方法執行 SQL 查詢 
cursor.execute("SELECT VERSION()")


# 使用 fetchone() 方法獲取單條資料.
data = cursor.fetchone()
print ("Database version : %s " % data)
db.commit()
# 關閉資料庫連線
#db.close()
# Out:
# Database version : 8.0.19
# /opt/conda/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1007, "Can't create database 'pttDB'; database exists")
#   result = self._query(query)

# %%
def create_mysql_table(board):
    # 使用 cursor() 方法建立一個遊標物件 cursor
    cursor = db.cursor()
    # 使用 execute()  方法執行 SQL 查詢 
    cursor.execute("create table if not exists {}( articleID varchar(10) primary key, authorId varchar(14),authorName varchar(14), category varchar(4),title varchar(20),publishedTime varchar(20),content text(65535),canonicalUrl varchar(64),createdTime varchar(30),updateTime varchar(30),commentId varchar(2048),commentContent varchar(2048),commentTime varchar(2048))").format(board)


    # 使用 fetchone() 方法獲取單條資料.
    data = cursor.fetchone()
    print ("Database version : %s " % data)
    db.commit()
    # 關閉資料庫連線
    #db.close()

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.116 Safari/537.36'

headers = {'User-Agent':user_agent}

# %%
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 nCoV2019 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/nCoV2019/index.html"><span class="board-label">看板 </span>nCoV2019</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/nCoV2019/index.html">看板</a>
# <a class="btn" href="/man/nCoV2019/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/nCoV2019/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/nCoV2019/index157.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/nCoV2019/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1582545062.A.B38.html">Re: [討論] 氣溫對肺炎的影響</a>
# </div>
# <div class="meta">
# <div class="author">waakye</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E6%B0%A3%E6%BA%AB%E5%B0%8D%E8%82%BA%E7%82%8E%E7%9A%84%E5%BD%B1%E9%9F%BF">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3Awaakye">搜尋看板內 waakye 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/24</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">38</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1582545533.A.142.html">[討論] 連兩天+2確診，大家是不是漸漸習慣麻痺了?</a>
# </div>
# <div class="meta">
# <div class="author">joanzkow</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E9%80%A3%E5%85%A9%E5%A4%A9%2B2%E7%A2%BA%E8%A8%BA%EF%BC%8C%E5%A4%A7%E5%AE%B6%E6%98%AF%E4%B8%8D%E6%98%AF%E6%BC%B8%E6%BC%B8%E7%BF%92%E6%85%A3%E9%BA%BB%E7%97%BA%E4%BA%86%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3Ajoanzkow">搜尋看板內 joanzkow 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/24</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1582547064.A.1FB.html">[新聞] 世衛聯合專家組：新冠病毒未明顯變異</a>
# </div>
# <div class="meta">
# <div class="author">Abre</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E4%B8%96%E8%A1%9B%E8%81%AF%E5%90%88%E5%B0%88%E5%AE%B6%E7%B5%84%EF%BC%9A%E6%96%B0%E5%86%A0%E7%97%85%E6%AF%92%E6%9C%AA%E6%98%8E%E9%A1%AF%E8%AE%8A%E7%95%B0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3AAbre">搜尋看板內 Abre 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/24</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
#
# 				(本文已被刪除) [ABBOBO]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 2/24</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1582547577.A.835.html">[討論] 中國的決策很奇怪</a>
# </div>
# <div class="meta">
# <div class="author">Kenver</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E4%B8%AD%E5%9C%8B%E7%9A%84%E6%B1%BA%E7%AD%96%E5%BE%88%E5%A5%87%E6%80%AA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3AKenver">搜尋看板內 Kenver 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/24</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1580005540.A.CFA.html">[情報] 武漢肺炎台灣及全球病例即時戰情儀表版</a>
# </div>
# <div class="meta">
# <div class="author">coffee777</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E6%AD%A6%E6%BC%A2%E8%82%BA%E7%82%8E%E5%8F%B0%E7%81%A3%E5%8F%8A%E5%85%A8%E7%90%83%E7%97%85%E4%BE%8B%E5%8D%B3%E6%99%82%E6%88%B0%E6%83%85%E5%84%80%E8%A1%A8%E7%89%88">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3Acoffee777">搜尋看板內 coffee777 的文章</a></div>
# </div>
# </div>
# <div class="date"> 1/26</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1580042407.A.564.html">[情報] 2/24 19:00 319|33國1648郵輪2374台30本14</a>
# </div>
# <div class="meta">
# <div class="author">ismail</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2%2F24+19%3A00+319%7C33%E5%9C%8B1648%E9%83%B5%E8%BC%AA2374%E5%8F%B030%E6%9C%AC14">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3Aismail">搜尋看板內 ismail 的文章</a></div>
# </div>
# </div>
# <div class="date"> 1/26</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1580893040.A.BA5.html">[情報] 2/22 06:20 領口罩懶人包V2.6</a>
# </div>
# <div class="meta">
# <div class="author">koan</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+2%2F22+06%3A20+%E9%A0%98%E5%8F%A3%E7%BD%A9%E6%87%B6%E4%BA%BA%E5%8C%85V2.6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3Akoan">搜尋看板內 koan 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/05</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">53</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1581054187.A.A90.html">[公告] 板規更新（新增推文規範、政治引戰罰則）</a>
# </div>
# <div class="meta">
# <div class="author">FlyFreedom</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8F%E6%9B%B4%E6%96%B0%EF%BC%88%E6%96%B0%E5%A2%9E%E6%8E%A8%E6%96%87%E8%A6%8F%E7%AF%84%E3%80%81%E6%94%BF%E6%B2%BB%E5%BC%95%E6%88%B0%E7%BD%B0%E5%89%87%EF%BC%89">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3AFlyFreedom">搜尋看板內 FlyFreedom 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/07</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">20</span></div>
# <div class="title">
# <a href="/bbs/nCoV2019/M.1581918360.A.408.html">[公告] 板上重要參考資訊彙整</a>
# </div>
# <div class="meta">
# <div class="author">flyingwhale</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/nCoV2019/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E4%B8%8A%E9%87%8D%E8%A6%81%E5%8F%83%E8%80%83%E8%B3%87%E8%A8%8A%E5%BD%99%E6%95%B4">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/nCoV2019/search?q=author%3Aflyingwhale">搜尋看板內 flyingwhale 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/17</div>
# <div class="mark">M</div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
#時間格式修改(資料建立時間與資料更新時間)
def time_convert(createdTime):
    import time 
    try:
        tempTime = time.strptime(createdTime,'%a %b %d %H:%M:%S %Y')
        resTime = time.strftime('%Y-%m-%dT%H:%M:%S.020+00:00',tempTime)
    except ValueError :
        tempTime = time.strptime(createdTime,' %m/%d/%Y %H:%M:%S')
        resTime = time.strftime('%Y-%m-%dT%H:%M:%S.020+00:00',tempTime)
    return resTime

#時間格式修改(貼文和推文時間改時間戳)
def time_mktime(publishedTime):
    import time
    try:
        resTime = str(round(time.mktime(time.strptime(publishedTime,'%a %b %d %H:%M:%S %Y')),))+"000"
    except Exception:
        resTime = str(round(time.mktime(time.strptime(publishedTime,' %Y %m/%d %H:%M')),))
    return resTime

#比較文章時間的格式修改
def compare_mktime(publishedTime):
    import time
    try:
        resTime = str(round(time.mktime(time.strptime(publishedTime,'%a %b %d %H:%M:%S %Y')),))
    except Exception:
        resTime = str(round(time.mktime(time.strptime(publishedTime,' %Y %m/%d %H:%M')),))
    return resTime

#推文的時間格式修改
def commentTime_mktime(commentTime_year):
    import time
    try:
        resTime = str(round(time.mktime(time.strptime(commentTime_year,' %Y %m/%d %H:%M:%S')),))
    except Exception:
        resTime = str(round(time.mktime(time.strptime(commentTime_year,' %Y %m/%d')),))
    return resTime

#頁數日期修改
def last_mktime(start_date_tmp):
    import time
    resTime = str(round(time.mktime(time.strptime(start_date_tmp,'%Y-%m-%d')),))
    return resTime

#文章內文
def content(artical_tmp):
    #artical_tmp = soup1.select('div[id="main-container"]')         
    artical_content = artical_tmp[0].text.split('--')[0]                      #文章內文
    print(artical_content)
    return artical_content

#完整推文    
def push_content(content_count):
    comment_word = []
    #content_count = soup3.select('div [class="push"] [class="f3 push-content"]')  #完整推文
    for count in range(0,len(content_count)):
        commentContent = content_count[count].text.replace(":","")
        comment_word.append(commentContent)
    print(comment_word)
    return comment_word

#推文作者    
def push_commentID(commentID_count):
    comment_user = []
    #commentID_count = soup3.select('div [class="push"] [class="f3 hl push-userid"]') #推文作者
    for count in range(0,len(commentID_count)):
        commentID = commentID_count[count].text
        comment_user.append(commentID)
    print(comment_user)
    return comment_user

#推文時間
def push_commentTime(artical_count,time_year): 
    #artical_count = soup3.select('div [class="push"] [class="push-ipdatetime"]')
    push_time = []
    for count in range(0,len(artical_count)):
        if len(artical_count[count].text) < 16 :                                      #判斷推文是否有時分秒，若有正常抓
            #print("推文有時分秒")
            commentTime_tmp = artical_count[count].text.replace('\n','')[-11:]          #推文時間
            print(commentTime_tmp)
            commentTime_year = '{} '.format(time_year)+commentTime_tmp
            print(commentTime_year)   
            commentTime = time_mktime(commentTime_year)
            #print("推文時間: "+commentTime)
        else:
            import time
            result = time.ctime() #若格式不一樣沒有時分秒  就調整格式
            hours = result[-13:-5]
            commentTime_tmp = artical_count[count].text.replace('\n','')[-5:]          #推文時間
            print(commentTime_tmp)
            commentTime_year = '{} '.format(time_year)+commentTime_tmp+" "+hours
            print(commentTime_year)   
            commentTime = commentTime_mktime(commentTime_year)
            #print("推文時間: "+commentTime)
        push_time.append(commentTime)
    print(push_time)
    return push_time

# %%
#擷取總頁數
def allpage_number(board):                                                    #擷取頁數
    urlpage = 'https://www.ptt.cc/bbs/{}/index.html'.format(board)
    res = requests.get(urlpage,headers = headers, cookies = {'over18':'1'})
    soup = BeautifulSoup(res.text, 'html.parser')
    allpageurl = soup.select('.btn.wide')[1]['href']
    start_index = allpageurl.find('index')
    end_index = allpageurl.find('.html')
    page_number = eval("%s +1" %(allpageurl[start_index + 5 : end_index]))
    print("總頁數",page_number)
    return page_number

# %%
'''
[爬下所設定的所有分類看板]
取出設定的其中一個看板，接著取出看板的所有頁數，再將每一頁的每篇文章的標題與網址取出
接著取得文章分類，文章分類有少部分格式不一樣，所以列為其他。

再來爬取貼文時間 文章內容 推文內容 推文作者 推文時間

'''
def all_board(class_board):
    for board in class_board:
        page_number = allpage_number(board)
        for page_count in range(page_number,0,-1):                       #抓取分類看板的所有頁數，再由最新抓回來
            time_year = 0
            url_allpage = 'https://www.ptt.cc/bbs/{}/index{}.html'.format(board,page_count)
            res = requests.get(url_allpage,headers = headers, cookies = {'over18':'1'})
            soup = BeautifulSoup(res.text, 'html.parser')
            title_url = soup.select('div[class="title"] a')
            print('第',page_count,'頁')
            for g,i in enumerate(title_url) :                            #取出分頁中各篇文章的網址
                try:
                    sort_tmp = i.text
                    sort = re.findall(r'\[\w\w',sort_tmp)[0].replace('[','')
                    print('文章分類為:'+ sort)                                     #文章分類
                except Exception :
                    print('文章分類為: 其他')
                try:
                    title = i.text.replace(' ','').split(']')[1]                  #文章標題
                    print(title)
                except Exception :
                    title = i.text
                    print(title)
                
                article_id_tmp = i['href']                                    #文章編號
                article_id = article_id_tmp[9:end_index].replace(".","")
                print(article_id)
                
                
                canonicalUrl = 'https://www.ptt.cc'+i['href']                 #標準網址
                print(canonicalUrl)
                autherID_tmp = soup.select('div[class="author"] ')            
                autherID = autherID_tmp[g].text                               #作者編號
                print('作者標號: '+autherID)
                url1= canonicalUrl
                res1 = requests.get(url1,headers = headers, cookies = {'over18':'1'})
                soup1 = BeautifulSoup(res1.text, 'html.parser')
                author = soup1.select('span[class="article-meta-value"]')
                try:
                    authorName_tmp = author[0].text.replace(')','').split('(')
                    authorName = authorName_tmp[1]
                    print('作者暱稱 '+authorName)                               #作者暱稱
                except Exception :
                    authorName = '沒有暱稱'
                    print(authorName)
                try:
                    time = soup1.select('span[class="article-meta-value"]')
                    someTime_tmp = time[3].text
                    time_year = someTime_tmp[-5:]
                    print("年分: "+time_year)
                    publishedTime = time_mktime(someTime_tmp)                   #貼文時間

                    print("貼文時間: "+publishedTime)
                except Exception :
                    createdTime = '版主公告 沒有時間'
                    print(createdTime)

                artical_tmp = soup1.select('div[id="main-container"]')
                artical_content = content(artical_tmp)                          #文章內文
                content_count = soup1.select('div [class="push"] [class="f3 push-content"]')
                comment_word = push_content(content_count)                      #推文內容
                commentID_count = soup1.select('div [class="push"] [class="f3 hl push-userid"]')
                comment_user = push_commentID(commentID_count)                  #推文作者
                artical_count = soup1.select('div [class="push"] [class="push-ipdatetime"]')
                try:
                    if time_year != 0:
                        push_time = push_commentTime(artical_count,time_year)   #推文時間
                    else:
                        updateTime_tmp11 = soup1.select('span[class="f2"]')
                        updateTime = updateTime_tmp11[3]
                        updateTime_convert = updateTime.text.replace('\n','').split(',')[1]
                        time_year = updateTime_convert[-13:-8]

                        push_time = push_commentTime(artical_count,time_year)   #推文時間
                except ValueError:
                    print("沒有推文時間")

# %%
'''
[指定欲擷取的貼文發布日期區間]
從最舊的文章開始搜尋，每一頁都抓當頁最新那篇文章的時間來與我要抓的起始時間比對，
如果當頁最新的那篇文章大於我要抓的起始時間，就會開始讀取當頁第一篇文章，再去
比較是不是介於我的起始時間與結束時間之中，如果符合再開始抓，避免在同一頁裡有
不符合時間區間的文章。

'''
def range_search(start_date,end_date,class_board): #抓設定範圍內的文章
    for board in class_board:
        page_number = allpage_number(board)
        for page_count in range(1,page_number):                                    #判斷每一頁的最後一篇文章
            url= 'https://www.ptt.cc/bbs/NBA/index{}.html'.format(page_count+1)
            print("第",page_count,"頁")
            res = requests.get(url,headers = headers, cookies = {'over18':'1'})    #請求分類看板首頁
            soup = BeautifulSoup(res.text, 'html.parser')
            last = soup.select('div [class="r-ent"] ')
            tmp_last = 'https://www.ptt.cc'+last[len(last)-1].a["href"]            #取出當前頁最後一篇文章網址
            print(tmp_last)
            try:
                res2 = requests.get(tmp_last,headers = headers, cookies = {'over18':'1'}) 
                soup_list = BeautifulSoup(res2.text, 'html.parser')
                time2 = soup_list.select('span[class="article-meta-value"]')
                someTime_tmp2 = time2[3].text
                lastTime2 = compare_mktime(someTime_tmp2)                    #當前頁面 最後一篇文章的貼文時間
                print("最後一篇貼文時間: "+lastTime2)
            except Exception :
                print('貼文時間關閉')

            if start_date <= lastTime2 :                                   #判斷每一頁的最後一篇文章的時間
                for compare_count in range(0,len(last)):
                    compare_url = 'https://www.ptt.cc'+last[compare_count].a['href']            #取出整頁文章網址
                    print('第',compare_count,'篇文章的URL :'+compare_url)
                    res3 = requests.get(compare_url,headers = headers, cookies = {'over18':'1'})
                    soup_content = BeautifulSoup(res3.text, 'html.parser')
                    try:
                        time3 = soup_content.select('span[class="article-meta-value"]')
                        someTime_tmp3 = time3[3].text
                        lastTime3 = compare_mktime(someTime_tmp3)                  #抓出第一篇文章時間
                        print('第一篇文章的時間'+lastTime3)
                    except Exception:
                        continue                                             #若文章被刪除，則換下一篇
                    if  lastTime3 >= start_date and lastTime3 <= end_date:      #第一篇文章時間大於起始時間就抓整頁文章
                        #20篇  #邊抓邊存 不要一次append完
                        time_year = 0
                        #for g,i in enumerate(title_url) :
                        try:
                            sort_tmp = last[compare_count].text
                            sort = re.findall(r'\[\w\w',sort_tmp)[0].replace('[','')
                            print('文章分類為:'+ sort)                                     #文章分類
                        except Exception :
                            print('文章分類為: 其他')
                            
                        
                        lastt = soup.select('div[class="title"] a')
                        try:
                            title = lastt[compare_count].text.replace(' ','').split(']')[1]                  #文章標題
                            print(title)
                        except Exception :
                            title = lastt[compare_count].text
                            print(title)
                        article_id_tmp = lastt[compare_count]['href']                         #文章編號
                        end_index = article_id_tmp.find('.html')
                        article_id = article_id_tmp[9:end_index].replace(".","")
                        print(article_id)
                        canonicalUrl = 'https://www.ptt.cc'+lastt[compare_count]['href']                 #標準網址
                        print(canonicalUrl)
                        
                        autherID_tmp = soup.select('div[class="author"] ')            
                        autherID = autherID_tmp[compare_count].text                               #作者編號
                        print('作者標號 : '+autherID)
                        author = soup_content.select('span[class="article-meta-value"]')
                        try:
                            authorName_tmp = author[0].text.replace(')','').split('(')
                            authorName = authorName_tmp[1]
                            print('作者暱稱 '+authorName)                                  #作者暱稱
                        except Exception :
                            authorName = '沒有暱稱'
                            print(authorName)
                        try:
                            time = soup_list.select('span[class="article-meta-value"]')
                            someTime_tmp = time[3].text
                            time_year = someTime_tmp[-5:]
                            print("年分: "+time_year)
                            publishedTime = time_mktime(someTime_tmp)                     #貼文時間

                            print("貼文時間: "+publishedTime)
                        except Exception :
                            createdTime = '版主公告 沒有時間'
                            print(createdTime)
     
                        artical_tmp = soup_content.select('div[id="main-container"]')
                        artical_content = content(artical_tmp)                      #文章內文
                        content_count = soup_content.select('div [class="push"] [class="f3 push-content"]')
                        comment_word = push_content(content_count)                  #推文內容
                        commentID_count = soup_content.select('div [class="push"] [class="f3 hl push-userid"]')
                        comment_user = push_commentID(commentID_count)              #推文作者
                        artical_count = soup_content.select('div [class="push"] [class="push-ipdatetime"]')
                        try:
                            if time_year != 0:
                                push_time = push_commentTime(artical_count,time_year)#推文時間
                                print('time正確')
                            else:
                                updateTime_tmp11 = soup_content.select('span[class="f2"]')
                                try:
                                    updateTime = updateTime_tmp11[3]
                                    updateTime_convert = updateTime.text.replace('\n','').split(',')[1]
                                    time_year = updateTime_convert[-13:-8]                            
                                    push_time = push_commentTime(artical_count,time_year)#推文時間
                                except Exception:
                                    print('沒有推文時間')
                        except ValueError:
                            print("沒有推文時間")
                    elif lastTime3 < end_date:                             #判斷
                        print('沒到起始時間')

                    else :
                        print('資料抓取完畢return')
                        return                                             #抓完時間內的文章後跳出

            else:
                pass

if __name__ =='__main__':
    
    db = pymysql.connect("mysql","root","123456","", )       #與mysql連線並創建資料庫
    cursor.execute("create database if not exists pttDB")
    db = pymysql.connect("mysql","root","123456","pttDB",charset='utf8' )
    
    start_date_tmp = input(str('起始時間 格式為2020-01-01 : '))#要抓的起始時間
    end_date_tmp   = input(str('結束時間 格式為2020-01-01 : '))#要抓的結束時間
    #如果兩個都沒輸入就直接全抓
    
    if start_date_tmp == '' and end_date_tmp == '' :
        print('---------------------全部都抓-----------------')
        class_board = ['NBA','nCoV2019','joke','Gossiping'] #可設定要抓哪幾個版
        all_board(class_board)
    else:
        try:
            start_date = last_mktime(start_date_tmp)
            end_date = last_mktime(end_date_tmp)
            print(start_date)
            print(end_date)                     
            class_board = ['NBA']  # 未來可增加抓多個版的功能
            print('--------------------抓區間------------------')
            range_search(start_date,end_date,class_board) 
        except Exception :
            print('輸入不正確')
# Out:
# 起始時間 格式為2020-01-01 :
# 結束時間 格式為2020-01-01 :
# ---------------------全部都抓-----------------
# 總頁數 6504
# 第 6504 頁
# 文章分類為:外絮
# Dlo說灰狼替他安排的輪休計畫是聰明的
# M1582615986A340
# https://www.ptt.cc/bbs/NBA/M.1582615986.A.340.html
# 作者標號: pneumo
# 作者暱稱 超☆冒險蓋
# 年分:  2020
# 貼文時間: 1582644781000
#
# 作者pneumo (超☆冒險蓋)看板NBA標題[外絮] Dlo說灰狼替他安排的輪休計畫是聰明的時間Tue Feb 25 15:33:01 2020
# 來源: StarTribune
# 網址: https://tinyurl.com/u2d3r3w
# D'Angelo Russell says Wolves' workload management plan for him is 'smart'
# D'Angelo Russell說灰狼替他安排的輪休計畫是聰明的
#
# DALLAS – D’Angelo Russell was back in uniform for the Timberwolves on
# 02/25 20:26
#  2020 02/25 20:26
# 推文時間: 1582662360
# 02/25 20:48
#  2020 02/25 20:48
# 推文時間: 1582663680
# 02/25 20:48
#  2020 02/25 20:48
# 推文時間: 1582663680
# 02/25 21:46
#  2020 02/25 21:46
# 推文時間: 1582667160
# 02/25 22:41
#  2020 02/25 22:41
# 推文時間: 1582670460
# 02/25 23:21
#  2020 02/25 23:21
# 推文時間: 1582672860
# 02/26 00:53
#  2020 02/26 00:53
# 推文時間: 1582678380
# ['1582645020', '1582645080', '1582645140', '1582645200', '1582645200', '1582645320', '1582645320', '1582645320', '1582645320', '1582645380', '1582645440', '1582645440', '1582645500', '1582645680', '1582645680', '1582645680', '1582645740', '1582645800', '1582645800', '1582645920', '1582646040', '1582646100', '1582646400', '1582646820', '1582647060', '1582647060', '1582647060', '1582647120', '1582647120', '1582647240', '1582647360', '1582647360', '1582647420', '1582647960', '1582648080', '1582648620', '1582651200', '1582651260', '1582651320', '1582651380', '1582651440', '1582651500', '1582651620', '1582651860', '1582652160', '1582652160', '1582652520', '1582652700', '1582652820', '1582652820', '1582653360', '1582653480', '1582653780', '1582653780', '1582653780', '1582653900', '1582654320', '1582655460', '1582656600', '1582656660', '1582656720', '1582658580', '1582660500', '1582660920', '1582662180', '1582662300', '1582662360', '1582663680', '1582663680', '1582667160', '1582670460', '1582672860', '1582678380']
# 文章分類為:花邊
# 總決賽若演世仇之戰　退役名將直言：綠衫
# M1582616945A7AA
# https://www.ptt.cc/bbs/NBA/M.1582616945.A.7AA.html
# 作者標號: fukawa947
# 作者暱稱 交大薛之謙
# 年分:  2020
# 貼文時間: 1582645742000
#
# 作者fukawa947 (交大薛之謙)看板NBA標題[花邊] 總決賽若演世仇之戰　退役名將直言：綠衫時間Tue Feb 25 15:49:02 2020
# NOWnews
# https://www.nownews.com/news/20200225/3955195/
#
# 記者劉祐廷 / 綜合報導
#
# 總決賽若演世仇之戰　退役名將直言：綠衫軍佔優勢
#
# https://i.imgur.com/p9yIvbv.jpg
# ▲湖人球星「詹皇」LeBron James突破重圍切入上籃。（圖／美聯社／達志影像）
#
# 昨(24)日波士頓塞爾提克與洛杉磯湖人的「世仇之戰」，綠衫軍以112:114不敵對手，不
# 過塞爾提克傳奇球星Paul Pierce(皮爾斯)對母隊很有信心，認為雙方就算在總冠軍戰碰
# 頭，也會是綠衫軍佔有優勢。
#
# 儘管湖人隊本季在LeBron James、Anthony Davis兩名巨星聯手下，以43勝12敗的成績稱
# 霸西區，但皮爾斯仍相當看好目前39勝17敗，在東區排名第3的塞爾提克。
#
# 皮爾斯表示：「如果這兩支球隊全員無缺的情況下在總決賽相遇，那塞爾提克在心理上佔
# 有優勢。我認為塞爾提克有NBA最強的先發5人，他們有幾個最好的得分前鋒，而就是現今
# 比賽贏球的關鍵。如果你回顧過去20年的總冠軍，然後問誰曾拿過總決賽MVP，答案就是
# 可以自己得分的搖擺人，像我皮爾斯這種，像Kobe Bryant這種。」
# https://www.youtube.com/watch?v=Ay-z4VECj8I&feature=emb_title
#
#
656420', '1582656480', '1582656660', '1582656720', '1582657320', '1582657440', '1582657740', '1582657980', '1582658040', '1582658040', '1582658580', '1582658760', '1582658760', '1582658880', '1582659900', '1582660320', '1582661820', '1582662420', '1582663800', '1582663800', '1582663860', '1582664340', '1582664700', '1582664700', '1582664760', '1582664760', '1582665720', '1582666740', '1582667580', '1582669440', '1582672740', '1582674120', '1582674720', '1582676100', '1582676100']
# 文章分類為:新聞
# 湖人有意補強外線傳可能試訓威特斯
# M1582620689A33B
# https://www.ptt.cc/bbs/NBA/M.1582620689.A.33B.html
# 作者標號: currykukuo
# 作者暱稱 陳菊濕汗
# 年分:  2020
# 貼文時間: 1582649486000
#
# 作者currykukuo (陳菊濕汗)看板NBA標題[新聞] 湖人有意補強外線 傳可能試訓威特斯時間Tue Feb 25 16:51:26 2020
# 2020-02-25 16:22 NBA台灣 / udn記者蔡佳霖／綜合外電報導
#
# 根據《ESPN》記者溫德霍斯特（Brian Windhorst）的消息，湖人傳出有意接觸威特斯（
# Dion Waiters），雙方有進行過會面，有可能會在近期安排試訓，不過是否會引進他，還
# 是未知數。
#
# 「我不確定威特斯是否會是答案，」溫德霍斯特說，「他們會給Dion一個展示機會。上週
# 他們進行過會面。我預計他們會在近期安排試訓，看看他現在的狀態。他們正在慎重考慮
# ，因為他們需要一個能得分的外線球員。」
#
# 值得一提的是，威特斯目前經紀人正是保羅（Rich Paul）。保羅旗下球員還包括詹姆斯
# （LeBron James）、戴維斯（Anthony Davis）等。不過能不能如願得到湖人的一紙合約
# ，還是得看威特斯的狀態。
#
# 「Dion不僅得用表現說服湖人球團，還需要得到詹姆斯的認同。」溫德霍斯特補充說道。
#
# 威斯特是在交易截止日前，透過三方交易被熱火交易到灰熊，不過灰熊隨後選擇將其裁掉
# 。
#
# 受到禁賽和傷勢影響，威特斯本季僅出賽3場，平均上場14分鐘，得到9分3.7籃板1助攻。
#
# 湖人近期放棄了卡珍斯（DeMarcus Cousins），改簽下前鋒莫里斯（Markieff Morris）
# 。隨著季後賽即將到來，湖人球團仍沒有放棄繼續補強陣容的想法。
#
# https://udn.com/news/story/7002/4369731?from=udn-catebreaknews_ch2
#
# 要進湖人484要先得到 #YOUNG KING 認證
#
#
# [' Dion Waiters是超級氣氛大師，連LBJ都很難收服。', ' 只剩下這種可撿，湖人真的慘', ' 封王大賽', ' 但他至少比JR好吧 JR這幾年只剩投籃 沒有自己創造得', ' 分機會的能力了', ' 連LBJ都收服不了那大概是沒救了', ' 刷子那裡好 命中率那麼低', ' 看成威斯特', ' 選他不如選JR...', ' 鎮不住吧', ' 這樣不具名球員怎麼辦', ' 選舞王吧', ' 前幾年版內文章 #1P0EO95o 中，Waiters還那麼崇拜', ' 裁表妹補一個 ， 那餵屎特要裁誰@@', ' Riley，結果才過一兩年和熱火的關係就崩掉了。', ' 慘，只剩服務生跟幸運的Kobe可撿', ' 舞王呢?', ' 看成威斯特...', ' 不看心魔的話 JR應該好一點吧', ' 寧願要JR', ' 簽一個跟霍大師一開始的非保障氣氛約吧', ' 這隻有比jr
# ['1582649520', '1582649580', '1582649580', '1582649640', '1582649640', '1582649700', '1582649760', '1582649820', '1582649940', '1582650000', '1582650000', '1582650060', '1582650060', '1582650060', '1582650120', '1582650120', '1582650240', '1582650360', '1582650420', '1582650420', '1582651080', '1582651080', '1582651260', '1582651320', '1582651320', '1582651620', '1582651680', '1582651800', '1582651920', '1582651980', '1582652100', '1582652100', '1582652100', '1582652160', '1582652160', '1582652220', '1582652220', '1582652280', '1582652280', '1582652280', '1582652340', '1582652460', '1582652460', '1582652520', '1582652580', '1582652640', '1582652820', '1582652820', '1582653120', '1582653240', '1582653360', '1582653420', '1582653660', '1582653720', '1582653900', '1582654080', '1582654200', '1582654500', '1582654560', '1582654560', '1582654560', '1582654800', '1582654860', '1582654860', '1582654920', '1582655040', '1582655220', '1582655400', '1582655820', '1582655880', '1582656480', '1582656840', '1582656840', '1582656960', '1582657440', '1582658160', '1582658400', '1582658580', '1582659480', '1582659540', '1582660320', '1582660860', '1582661160', '1582662600', '1582662780', '1582663620', '1582664040', '1582664700', '1582664940', '1582666320', '1582666620', '1582667340', '1582667400', '1582668120', '1582669980', '1582670280', '1582671180', '1582671180', '1582671180', '1582673100', '1582677240']
# 文章分類為:新聞
# 參加追思會後趕回主場出賽　哈登：我必
# M1582624348A64A
# https://www.ptt.cc/bbs/NBA/M.1582624348.A.64A.html
# 作者標號: ericcharng
# 作者暱稱 常
# 年分:  2020
# 貼文時間: 1582653145000
#
# 作者ericcharng (常)看板NBA標題Re: [新聞] 參加追思會後趕回主場出賽　哈登：我必時間Tue Feb 25 17:52:25 2020
# 推文在討論NBA五絕
#
# 有些錯誤來導正
#
# 五絕分自幹五絕還有當時的聯盟頂尖球員五絕
#
# 因為都是從東邪西毒衍伸而來的所以前兩人一樣
#
# 中都是以Kobe為首
#
# 自幹五絕 除了Kobe因為要湊自幹之王
#
# 當時很符合地理位置
#
# 東羅 羅斯 Rose 芝加哥
#
# 西河 西河 Westbrook 奧克拉荷馬
#
# 南尼 尼二審 Nelson 奧蘭多 美國南端佛羅里達
#
# 北莫 莫不傳 Mo Williams 北大荒密爾瓦基
#
# 中神科 老大 Kobe Bryant
#
# 頂尖五絕 是為了符合金庸五絕的音衍伸而來
#
# 東鞋 Rose
#
# 西獨 Westbrook
#
# 南帝 小皇帝 LBJ
#
# 北丐 當時還有開圓的圓仔 Durant
#
# 中神科 Kobe
#
# 要注意 要飯（要犯）= 丐幫
#
# 是KD開啟這個說法的 不是Harden
#
# 推文把現今丐幫幫主Harden誤植成北丐
#
# 其實是錯誤的
#
# 當時的Harden還在雷霆當三弟
#
# 也還沒練成要飯神功
#
# 不要搞錯了
#
#
#
#
#
# [' 丐幫總是要換幫主的', ' 一堆四年老勇獼你期待他們科普老人梗？', ' 好久以前的梗 哈哈', ' 當年的圓歷歷在目', ' 幫主底下有執法、傳功長老，然後九袋弟子', ' 嘔嘔嘔4老人臭 >w<', ' 這梗真的歷史悠久但朗朗上口XD', ' 當時KD的圓可是A社團的造圖利器', ' 我怎麼記得這是第二版本了 有個沒Rose跟西合的吧?', ' 記得以前還有武俠體NBA文，歷歷在目', ' 所以這才是NBA正史嗎', ' 哈登是污衣派還是淨衣派？', ' RoseC好久沒發文了 難過', ' 哈登去火箭之後 熱火 雷霆 火箭 NBA三大黑哨...', ' 當年雷霆的BOX. 也是很精彩', ' 這篇雖然前面對 但後面 又有人重排了', '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-433-0c3886e858f2> in <module>
#     131         print('---------------------全部都抓-----------------')
#     132         class_board = ['NBA','nCoV2019','joke','Gossiping'] #可設定要抓哪幾個版
# --> 133         all_board(class_board)
#     134     else:
#     135         try:
#
# <ipython-input-432-155424861e16> in all_board(class_board)
#      35                 print('作者標號: '+autherID)
#      36                 url1= canonicalUrl
# ---> 37                 res1 = requests.get(url1,headers = headers, cookies = {'over18':'1'})
#      38                 soup1 = BeautifulSoup(res1.text, 'html.parser')
#      39                 author = soup1.select('span[class="article-meta-value"]')
#
# /opt/conda/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/conda/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/conda/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/conda/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /opt/conda/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# /opt/conda/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/conda/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/conda/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/conda/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
sort_tmp = i.text
sort = re.findall(r'\[\w\w',sort_tmp)[0].replace('[','')
print('文章分類為:'+ sort)
# Out:
# 起始時間 格式為2020-01-01
# ''

# %%
if start_date_tmp == '':
    print('ok')
else:
    print("NO")
# Out:
# ok

# %%
i['href'][16:26]+'000'
# Out:
# '1581918360000'

# %%
url1= 'https://www.ptt.cc/bbs/nCoV2019/M.1582211618.A.1F0.html'

res1 = requests.get(url1,headers = headers, cookies = {'over18':'1'})
soup1 = BeautifulSoup(res1.text, 'html.parser')

# %%
soup1
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <meta content="0" http-equiv="refresh"/>
# <title>www.ptt.cc | 522: Connection timed out</title>
# <meta charset="utf-8">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" type="text/css" media="screen,projection" /><![endif]-->
# <style type="text/css">body{margin:0;padding:0}</style>
# </meta></head>
# <body>
# <div id="cf-wrapper">
# <div class="cf-error-details-wrapper" id="cf-error-details">
# <div class="cf-wrapper cf-error-overview">
# <h1>
# <span class="cf-error-type">Error</span>
# <span class="cf-error-code">522</span>
# <small class="heading-ray-id">Ray ID: 5689cd23c9d7efbc • 2020-02-21 15:37:54 UTC</small>
# </h1>
# <h2 class="cf-subheadline">Connection timed out</h2>
# </div><!-- /.error-overview -->
# <div class="cf-section cf-highlight cf-status-display">
# <div class="cf-wrapper">
# <div class="cf-columns cols-3">
# <div class="cf-column cf-status-item cf-browser-status" id="cf-browser-status">
# <div class="cf-icon-error-container">
# <i class="cf-icon cf-icon-browser"></i>
# <i class="cf-icon-status cf-icon-ok"></i>
# </div>
# <span class="cf-status-desc">You</span>
# <h3 class="cf-status-name">Browser</h3>
# <span class="cf-status-label">Working</span>
# </div>
# <div class="cf-column cf-status-item cf-cloudflare-status" id="cf-cloudflare-status">
# <div class="cf-icon-error-container">
# <i class="cf-icon cf-icon-cloud"></i>
# <i class="cf-icon-status cf-icon-ok"></i>
# </div>
# <span class="cf-status-desc">Tokyo</span>
# <h3 class="cf-status-name">Cloudflare</h3>
# <span class="cf-status-label">Working</span>
# </div>
# <div class="cf-column cf-status-item cf-host-status cf-error-source" id="cf-host-status">
# <div class="cf-icon-error-container">
# <i class="cf-icon cf-icon-server"></i>
# <i class="cf-icon-status cf-icon-error"></i>
# </div>
# <span class="cf-status-desc">www.ptt.cc</span>
# <h3 class="cf-status-name">Host</h3>
# <span class="cf-status-label">Error</span>
# </div>
# </div>
# </div>
# </div><!-- /.status-display -->
# <div class="cf-section cf-wrapper">
# <div class="cf-columns two">
# <div class="cf-column">
# <h2>What happened?</h2>
# <p>The initial connection between Cloudflare's network and the origin web server timed out. As a result, the web page can not be displayed.</p>
# </div>
# <div class="cf-column">
# <h2>What can I do?</h2>
# <h5>If you're a visitor of this website:</h5>
# <p>Please try again in a few minutes.</p>
# <h5>If you're the owner of this website:</h5>
# <p><span>Contact your hosting provider letting them know your web server is not completing requests. An Error 522 means that the request was able to connect to your web server, but that the request didn't finish. The most likely cause is that something on your server is hogging resources.</span> <a href="https://support.cloudflare.com/hc/en-us/articles/200171906-Error-522">Additional troubleshooting information here.</a></p>
# </div>
# </div>
# </div><!-- /.section -->
# <div class="cf-error-footer cf-wrapper">
# <p>
# <span class="cf-footer-item">Cloudflare Ray ID: <strong>5689cd23c9d7efbc</strong></span>
# <span class="cf-footer-separator">•</span>
# <span class="cf-footer-item"><span>Your IP</span>: 223.137.110.60</span>
# <span class="cf-footer-separator">•</span>
# <span class="cf-footer-item"><span>Performance &amp; security by</span> <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=error_footer" id="brand_link" target="_blank">Cloudflare</a></span>
# </p>
# </div><!-- /.error-footer -->
# </div><!-- /#cf-error-details -->
# </div><!-- /#cf-wrapper -->
# </body>
# </html>

# %%
author = soup1.select('span[class="article-meta-value"]')
authorName_tmp = author[0].text.replace(')','').split('(')
authorName = authorName_tmp[1]
# Out:
# 'cluster'

# %%
time = soup1.select('span[class="article-meta-value"]')
someTime_tmp = time[3].text
createdTime = time_convert(someTime_tmp)                       #貼文時間
# Out:
# '2020-02-20T23:13:36.020+00:00'

# %%
#時間格式修改
def time_convert(createdTime):
    import time
    tempTime = time.strptime(createdTime,'%a %b %d %H:%M:%S %Y')
    resTime = time.strftime('%Y-%m-%dT%H:%M:%S.020+00:00',tempTime)
    return resTime

# %%
title = i.text
title.split(']')[1]            #文章標題
# Out:
# ' 板上重要參考資訊彙整'

# %%
re.findall(r'\[\w\w',jijiji)[0].replace('[','')
# Out:
# '問題'

# %%
re.findall(r'^Re: \[.*\]',title)
# Out:
# []

# %%
cata  = soup1.select('div[class="bbs-content"] a')
class_board = cata[1].text.replace('看板 ','')             #看板
# Out:
# 'nCoV2019'

# %%
soup1
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <meta content="0" http-equiv="refresh"/>
# <title>www.ptt.cc | 522: Connection timed out</title>
# <meta charset="utf-8">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" type="text/css" media="screen,projection" /><![endif]-->
# <style type="text/css">body{margin:0;padding:0}</style>
# </meta></head>
# <body>
# <div id="cf-wrapper">
# <div class="cf-error-details-wrapper" id="cf-error-details">
# <div class="cf-wrapper cf-error-overview">
# <h1>
# <span class="cf-error-type">Error</span>
# <span class="cf-error-code">522</span>
# <small class="heading-ray-id">Ray ID: 5689cd23c9d7efbc • 2020-02-21 15:37:54 UTC</small>
# </h1>
# <h2 class="cf-subheadline">Connection timed out</h2>
# </div><!-- /.error-overview -->
# <div class="cf-section cf-highlight cf-status-display">
# <div class="cf-wrapper">
# <div class="cf-columns cols-3">
# <div class="cf-column cf-status-item cf-browser-status" id="cf-browser-status">
# <div class="cf-icon-error-container">
# <i class="cf-icon cf-icon-browser"></i>
# <i class="cf-icon-status cf-icon-ok"></i>
# </div>
# <span class="cf-status-desc">You</span>
# <h3 class="cf-status-name">Browser</h3>
# <span class="cf-status-label">Working</span>
# </div>
# <div class="cf-column cf-status-item cf-cloudflare-status" id="cf-cloudflare-status">
# <div class="cf-icon-error-container">
# <i class="cf-icon cf-icon-cloud"></i>
# <i class="cf-icon-status cf-icon-ok"></i>
# </div>
# <span class="cf-status-desc">Tokyo</span>
# <h3 class="cf-status-name">Cloudflare</h3>
# <span class="cf-status-label">Working</span>
# </div>
# <div class="cf-column cf-status-item cf-host-status cf-error-source" id="cf-host-status">
# <div class="cf-icon-error-container">
# <i class="cf-icon cf-icon-server"></i>
# <i class="cf-icon-status cf-icon-error"></i>
# </div>
# <span class="cf-status-desc">www.ptt.cc</span>
# <h3 class="cf-status-name">Host</h3>
# <span class="cf-status-label">Error</span>
# </div>
# </div>
# </div>
# </div><!-- /.status-display -->
# <div class="cf-section cf-wrapper">
# <div class="cf-columns two">
# <div class="cf-column">
# <h2>What happened?</h2>
# <p>The initial connection between Cloudflare's network and the origin web server timed out. As a result, the web page can not be displayed.</p>
# </div>
# <div class="cf-column">
# <h2>What can I do?</h2>
# <h5>If you're a visitor of this website:</h5>
# <p>Please try again in a few minutes.</p>
# <h5>If you're the owner of this website:</h5>
# <p><span>Contact your hosting provider letting them know your web server is not completing requests. An Error 522 means that the request was able to connect to your web server, but that the request didn't finish. The most likely cause is that something on your server is hogging resources.</span> <a href="https://support.cloudflare.com/hc/en-us/articles/200171906-Error-522">Additional troubleshooting information here.</a></p>
# </div>
# </div>
# </div><!-- /.section -->
# <div class="cf-error-footer cf-wrapper">
# <p>
# <span class="cf-footer-item">Cloudflare Ray ID: <strong>5689cd23c9d7efbc</strong></span>
# <span class="cf-footer-separator">•</span>
# <span class="cf-footer-item"><span>Your IP</span>: 223.137.110.60</span>
# <span class="cf-footer-separator">•</span>
# <span class="cf-footer-item"><span>Performance &amp; security by</span> <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=error_footer" id="brand_link" target="_blank">Cloudflare</a></span>
# </p>
# </div><!-- /.error-footer -->
# </div><!-- /#cf-error-details -->
# </div><!-- /#cf-wrapper -->
# </body>
# </html>

# %%
#抓文章內文--有作者資訊來得及就修正
artical_tmp = soup1.select('div[id="main-container"]')
artical_content = artical_tmp[0].text.split('--')[0]
print(artical_content)
# Out:
# 作者raiderho (冷顏冷雨)看板nCoV2019標題Re: [討論] 公布病患所在區域造成的影響時間Sun Feb 23 12:33:28 2020
#
# 我本來以為這關係到「公開透明」 (或換句話說「知情權」)，這本質是「信任社會體制
# 到什麼程度」的問題，結果從推文和相關討論發現某些人根本沒思考防疫體系的決策邏輯。
#
# 我知道很多人提過了，但再講一次或許有其必要。
#
# ===
#
# 引用陳時中的話：
# 地方政府一定會知道（第24例確診個案資訊），因為衛生局是一起啟動的。而政府的態度
# 很清楚，能掌握的特定對象，他們不公布；他們不能掌握的特定對象，他們公布。
#
#
# 因此我們有如下邏輯推論：
#
# 假如你信任防疫體系的專業，他們選擇不公開，因為他們根據已有資訊，掌握已經有風險
# 的人員名單。對此，防疫專業人員判斷控管這些人對防疫需求已經足夠，不需要再額外公
# 布資訊，造成獵巫或社會不必要恐慌，耗費大量社會成本，包括現階段不必要的檢疫。 (
# 這些是前幾天陳時中已經多次表達的觀念。)
#
# 若一個人沒被通知要隔離，代表防疫專家們根據現有資訊，推斷他風險小到不需要耗費資
# 源檢測，他就算知道病患20天前經過某地點，也毫無意義。他需要的只是如同平常一樣注
# 意自己的衛生習慣。
#
# 防疫體系之前的做法完全遵照以上的準則，唯二公布具體地點或路線的金巴黎和鑽石公主
# 號也是如此：前者舞廳流動客人甚多，必須公布讓客人自己有警覺心；後者更是完全無法
# 追蹤，數量又龐大，因此直接採用國家級警報。那第24例呢，源頭此刻仍然未知，但源頭
# 也早過了14天，該爆發的都爆發了，幸好結果沒有，所以就算追查不到也無礙，而後來的
# 接觸史已經被防疫體系掌握了。
#
#
# ===
#
#
# 補充：
#
# 1.
# 若不接受這些說法，除非是欠缺邏輯推論能力，那只可能是「不相信防疫體系」。防疫體
# 系迄今表現非常穩健，若仍然不受信任，大概怎麼做都不會受到信任了。
#
# 我原本以為有些人選擇不信任，所以我想問的本來是為何「不信任」，或者為何「從信任
# 到不信任」，結果某些人根本沒理解防疫體系的邏輯。
#
# 2.
# 也有蠻多版友提過了...
# 要討論「公開透明」到什麼地步當然可以啦，但其實應該問「防疫體系」這樣的做法在此
# 時此刻有什麼缺失吧。我信任專業人士，從邏輯上也看不出缺失啦，那所以「公開更多資
# 訊」有什麼好處？
#
# 3.
# 你要回覆知情權也可以，但請論述一下知情權的界定和其範圍，有沒有暫時的權宜做法。
# 公開資訊的原則之一是為了讓人民善用這些資訊保護自己，那這次「公布地點」 (無論到
# 縣市鄉鎮還是鄰里) 能多保護人民什麼呢？請不要舉例之前其他法定傳染病疫情資料的呈現
# 方式，竊以為這無法與這次帶有嚴重民眾負面情緒 (比如獵巫、歧視或霸凌) 的事相類比，
# 當然更和登革熱這種蚊蟲地域性傳染病不一樣了。

# %%
#作者最後更新時間
updateTime_tmp = soup1.select('span[class="f2"]')
updateTime = updateTime_tmp[len(updateTime_tmp)-1]
updateTime_convert = updateTime.text.replace('\n','').split(',')[1]
time_convert(updateTime_convert)
# Out:
# '2020-02-20T23:21:58.020+00:00'

# %%
import time
time.strptime(updateTime_convert,' %m/%d/%Y %H:%M:%S')
# Out:
# time.struct_time(tm_year=2020, tm_mon=2, tm_mday=20, tm_hour=23, tm_min=21, tm_sec=58, tm_wday=3, tm_yday=51, tm_isdst=-1)

# %%
#資料建立時間，在存入mongo時放入
import time
createdTime = time.strftime('%Y-%m-%dT%H:%M:%S.020+00:00',time.localtime())
#資料更新時間，待處理
# Out:
# '2020-02-21T15:23:11.020+00:00'

# %%
#推文者 編號  內容  時間
artical_tmp[0].text.split('--')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-406-f8f480d91555> in <module>
#       1 #推文者 編號  內容  時間
# ----> 2 artical_tmp[0].text.split('--')[0]
#
# IndexError: list index out of range

# %%
#將版的總頁數取出，跑頁數迴圈

# %%
#  2.抓哪個區間

# %%
#轉成dataframe
df = pd.DataFrame(columns =['標題','日期','作者','網址','內文'])#設定PD
DATA = []
DATA.append(title_all[0].text.replace('\n','').replace('\r','').replace(' ',''))#標題
DATA.append(date[0].text)#時間
DATA.append(author[0].text)#作者
DATA.append(url2)#網址
DATA.append(content_all.replace('\n','').replace('\r','').replace(' ',''))#內文
df.loc[G]=DATA#df結合DATA

# %%
#將dataframe塞進資料庫

# %%
d1 = datetime.datetime.strptime('2012-03-07','%Y-%m-%d')
d2 = datetime.datetime.strptime('2012-03-12','%Y-%m-%d')

delta = abs(d1 - d2)
add_date = delta.days
add_date
# Out:
# 5

# %%
from datetime import date
import time
from dateutil.rrule import rrule, DAILY
#時間抓取設定

start_date = date(2018, 1,1)
print(start_date)
end_date = date(2018, 1, 7)
gg = ''.join(dt.strftime("%Y%m%d\n") for dt in rrule(DAILY, dtstart=start_date, until=end_date))
ggg = gg.split('\n')
print(ggg[3])
for aaa in ggg:
    print(str(round(time.mktime(time.strptime(aaa,'%Y%m%d')),)))
#print(dt.strftime("%Y%m%d"))
# Out:
# 2018-01-01
# 20180104
# 1514764800
# 1514851200
# 1514937600
# 1515024000
# 1515110400
# 1515196800
# 1515283200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-290-1c30b7791c5d> in <module>
#      11 print(ggg[3])
#      12 for aaa in ggg:
# ---> 13     print(str(round(time.mktime(time.strptime(aaa,'%Y%m%d')),)))
#      14 #print(dt.strftime("%Y%m%d"))
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime_time(data_string, format)
#     569     """Return a time struct based on the input string and the
#     570     format string."""
# --> 571     tt = _strptime(data_string, format)[0]
#     572     return time.struct_time(tt[:time._STRUCT_TM_ITEMS])
#     573
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
#     361         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '' does not match format '%Y%m%d'

# %%
import datetime
from datetime import datetime
from dateutil.parser import parse
published_time = datetime.now()
a = '2019-07-08'
startdate = parse("{}".format(a))
enddate = parse("2020-6-8")
startdate<published_time<enddate
if startdate <= published_time and published_time <= enddate:
# Out:
# True

# %%
import time
a = "2020-02-20T23:13:36"
print(time.strptime(a,"%Y-%m-%dT%H:%M:%S"))
print(time.mktime(time.strptime(a,"%Y-%m-%dT%H:%M:%S")))
print(str(round(time.mktime(time.strptime(a,"%Y-%m-%dT%H:%M:%S")),))+"000")
# Out:
# time.struct_time(tm_year=2020, tm_mon=2, tm_mday=20, tm_hour=23, tm_min=13, tm_sec=36, tm_wday=3, tm_yday=51, tm_isdst=-1)
# 1582240416.0
# 1582240416000

# %%
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>[問題] 請教這款洗手液的酒精濃度? - 看板 nCoV2019 - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content=" 我在新加坡這邊的量販超市詢問
#  他們現在有提供一款叫做ultra compact hand sanitizer
# https://i.imgur.com/kIp604e.jpg
# https://i.imgur.com/P2RgYcY.jpg
#  原產地是土耳其
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="[問題] 請教這款洗手液的酒精濃度?" property="og:title"/>
# <meta content=" 我在新加坡這邊的量販超市詢問
#  他們現在有提供一款叫做ultra compact hand sanitizer
# https://i.imgur.com/kIp604e.jpg
# https://i.imgur.com/P2RgYcY.jpg
#  原產地是土耳其
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/nCoV2019/M.1582211618.A.1F0.html" rel="canonical"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/nCoV2019/index.html"><span class="board-label">看板 </span>nCoV2019</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="navigation-container">
# <div class="bbs-content" id="navigation">
# <a class="board" href="/bbs/nCoV2019/index.html">返回看板</a>
# <div class="bar"></div>
# </div>
# </div>
# <div id="main-container">
# <div class="bbs-screen bbs-content" id="main-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">davidwales (cluster)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">nCoV2019</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[問題] 請教這款洗手液的酒精濃度?</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Thu Feb 20 23:13:36 2020</span></div>
#
#  我在新加坡這邊的量販超市詢問
#
#  他們現在有提供一款叫做ultra compact hand sanitizer
#
#
# <a href="https://i.imgur.com/kIp604e.jpg" rel="nofollow" target="_blank">https://i.imgur.com/kIp604e.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="kIp604e" lang="en"><a href="//imgur.com/kIp604e"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div>
# <a href="https://i.imgur.com/P2RgYcY.jpg" rel="nofollow" target="_blank">https://i.imgur.com/P2RgYcY.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="P2RgYcY" lang="en"><a href="//imgur.com/P2RgYcY"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div>
#  原產地是土耳其
#
#  但我一直搜尋不到他的酒精濃度是否為75%
#
#  不知道能否請教各位?
#
#  有人知道這款商品是否能夠有效殺死新冠病毒,謝謝!
#
#
#
#
#
#
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 219.74.195.140 (新加坡)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/nCoV2019/M.1582211618.A.1F0.html" rel="nofollow" target="_blank">https://www.ptt.cc/bbs/nCoV2019/M.1582211618.A.1F0.html</a>
# </span><span class="f2">※ 編輯: davidwales (111.65.45.100 新加坡), 02/20/2020 23:15:56
# </span><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">
>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
artical_tmp = soup1.select('div [class="push"] [class="f3 push-content"]')
artical_tmp[0].text.replace(":","")                  #完整推文
# Out:
# ' 辛苦了!'

# %%
artical_tmp = soup1.select('div [class="push"] [class="f3 hl push-userid"]')
artical_tmp[0].text                                  #推文作者
# Out:
# 'zold'

# %%
artical_tmp = soup1.select('div [class="push"] [class="push-ipdatetime"]')
artical_tmp[0].text.replace('\n','')[-11:]          #推文時間
# Out:
# '02/05 16:57'

# %%
artical_tmp1 = soup1.select('div [class="push"]')
artical_tmp1
# Out:
# [<div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zold</span><span class="f3 push-content">: 加油！</span><span class="push-ipdatetime"> 02/05 16:57
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 辛苦了!</span><span class="push-ipdatetime"> 02/05 17:01
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">sad0soul</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:01
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">xhakiboo</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:02
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">snownow</span><span class="f3 push-content">: 覺得除非完全沒有的人，不然開放第一周最好別去拿XD</span><span class="push-ipdatetime"> 02/05 17:02
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">snownow</span><span class="f3 push-content">: 太緊急上線了，可能實務會出很多小麻煩，而且領的人也多</span><span class="push-ipdatetime"> 02/05 17:02
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">senstivewu</span><span class="f3 push-content">: 推！</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">aeoleron</span><span class="f3 push-content">: 辛苦了</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lonven</span><span class="f3 push-content">: 真的要講自備乾淨袋子，因為我相信那也是成本不是每個藥</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lonven</span><span class="f3 push-content">: 局都有提供</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">recx</span><span class="f3 push-content">: 我覺得從買了之後算這點不太好 一定開放前兩天通通擠過去</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">fishwan</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">recx</span><span class="f3 push-content">: 不然越晚買下次就要等越久 不是把量分散在七天內比較好?</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zold</span><span class="f3 push-content">: 我都自備「塑膠袋」去買口罩， 節省成本！</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Doralice</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:05
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">hwider</span><span class="f3 push-content">: 推推</span><span class="push-ipdatetime"> 02/05 17:05
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Doralice</span><span class="f3 push-content">: 有庫存的就不必去擠頭兩天</span><span class="push-ipdatetime"> 02/05 17:06
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">qqq5890003</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:08
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zold</span><span class="f3 push-content">: 沒錯，頭兩天人最多， 可以晚點去</span><span class="push-ipdatetime"> 02/05 17:10
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Baltokalin</span><span class="f3 push-content">: 雖然實行前還是觀望，但是果然是類似比照慢簽或領藥</span><span class="push-ipdatetime"> 02/05 17:10
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Baltokalin</span><span class="f3 push-content">: 過卡異常這樣好控管，政策給推</span><span class="push-ipdatetime"> 02/05 17:10
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">all0917</span><span class="f3 push-content">: 推！詳細解說</span><span class="push-ipdatetime"> 02/05 17:14
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ROCAF</span><span class="f3 push-content">: 訛啦 靴是要踹人嗎XD</span><span class="push-ipdatetime"> 02/05 17:15
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">happyLynn</span><span class="f3 push-content">: 家裡還有的人不用去跟急需要的人排！晚點去即可</span><span class="push-ipdatetime"> 02/05 17:16
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Juinsy</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:16
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jcamnos</span><span class="f3 push-content">: 推!!      是以訛傳訛啦 XDD</span><span class="push-ipdatetime"> 02/05 17:18
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">groo</span><span class="f3 push-content">: 之前說依照身分證最後一碼，可是內文說依照健保卡號？</span><span class="push-ipdatetime"> 02/05 17:19
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">laechan</span><span class="f3 push-content">: 長網址...</span><span class="push-ipdatetime"> 02/05 17:21
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tiyehpai</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:22
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">xj4bp6ejo3</span><span class="f3 push-content">: 今天看到有人從藥局出來拿一疊口罩（裸裝）</span><span class="push-ipdatetime"> 02/05 17:22
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">anguslf2</span><span class="f3 push-content">: 還好我親戚家開藥局</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lightwing</span><span class="f3 push-content">: 系統還沒上線，藥師也不熟悉，要限2小時賣完不然鎖系</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightwing</span><span class="f3 push-content">: 統，啊你是有把握能限時處理完嗎？</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">witcherysky</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">NCUking</span><span class="f3 push-content">: 沒有限兩個小時要賣完吧</span><span class="push-ipdatetime"> 02/05 17:25
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ThisIsNotKFC</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:26
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">cruby841031</span><span class="f3 push-content">: 哪裡有說限兩小時?</span><span class="push-ipdatetime"> 02/05 17:27
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">KunioFAN</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:27
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">DialUp</span><span class="f3 push-content">: 推！請大家多給工作人員一點鼓勵和耐心，少些責備。艱難時</span><span class="push-ipdatetime"> 02/05 17:28
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 推k大真的很有耐心溫和地有問必答耶XD</span><span class="push-ipdatetime"> 103.10.197.102 02/20 21:32
#  </span></div>]

# %%
def push_content(artical_tmp)
    artical_tmp = soup1.select('div [class="push"] [class="f3 push-content"]')
    commentId = artical_tmp[0].text.replace(":","")                  #完整推文
    artical_tmp = soup1.select('div [class="push"] [class="f3 hl push-userid"]')
    commentContent = artical_tmp[0].text                                  #推文作者
    artical_tmp = soup1.select('div [class="push"] [class="push-ipdatetime"]')
    commentTime_tmp = artical_tmp[0].text.replace('\n','')[-11:]           #推文時間
    commentTime = cotime_mktime(commentTime_tmp)
    return commentId,commentContent,commentTime

# %%
for count,artical_count in enumerate (artical_tmp):
        artical_count = soup1.select('div[id="main-container"]')         
        artical_content = artical_tmp[count].text.split('--')[0]                 #文章內文
        print(artical_content)
        print('-------------------')
# Out:
# 2020 2/22 06:20 update V2.6
# 更新全文"小孩"定義(ref24
# 原本97後(12歲)更改為96後(13歲)
#
# 2020 2/19 22:10 update V2.52
# 1. 更新懶人包第3點(ref22
# 小孩買大人的口罩維持2片10元
# 且選買大人小孩時只能擇一不能混搭
# 2. 刪除中國官方可見數據
# 無統計意義
#
# 2020 2/17 20:30 update V2.5
# 1. 更新懶人包第2點
# 增加大人口罩量200片至400片
# 增加小孩口罩量100片至200片
# 2. 更新懶人包第3點
# 小孩買小孩的量2片10元增為4片20元
#
# 2020 2/15 18:20 update V2.41
# 1. 更新懶人包第5點
# 2. 更新中國官方可見數據
#
# 2020 2/15 17:30 update V2.4
# 1. 更新懶人包第1點
# 新增303家衛生所可以領口罩啦
# 懶人包第5點證件部分稍不同(V2.41更新)
# 2. 更新懶人包第3點
# 如果發生時間未到的糾紛請打1919
# 3. 更改錯字正妹護理藍博士為許博士
#
# 2020 2/12 21:30 update V2.3
# 1. 新增懶人包第7點
# 口罩公差(志工)上線啦
# 2. 更新中國官方可見數據
#
# 2020 2/11 14:30 update V2.2
# 1. 更新96後小孩領大人口罩流程圖
# 在懶人包第4點(拜託請有禮貌)
# 2. 更新中國官方可見數據
# 3. 更新懶人包第3點細節
#
# 2020 2/9 11:00 update V2.1
# 1. 更新口罩實名制系統開機時間
# 為07:00-2200 (原08:00-2200)
# 2. 更新中國官方可見數據
#
# 2020 2/8 13:40 update V2.0
# 1. 全文重新編排、縮網址
# 2. 更新目前可知傳染方式
# 數據統計、危險族群
# 建議戴口罩時機及洗手步驟細節
#
# 2020 2/7 18:40 update V1.1
# 購買身份細節更新
#
#
# 目前武漢肺炎的傳播方式
# 可以確定的是呼吸道飛沫及接觸傳播(ref1
# 尚未確定的是母嬰及口糞傳播(ref2, 3
#
# 危險族群是老人和有慢性疾病者(ref1
# 兒童病例症狀較為輕微
#
#
# 目前我們能做到的是
#
#
# A. 預防呼吸道飛沫傳播：
#
# 如果上課、工作及社交需要
# 去人多、密閉空間的地方
# "我個人"建議要戴口罩
#
# 空曠地方控土窯、爬山或宅在家
# 這些不戴是非常正常的
#
#
# 怎麼戴？
# 一般通則是顏色深(粗糙)的朝外
# 壓住鼻樑鐵片
# 拉開口罩下緣至下巴處
# 耳朵再掛起(先掛後掛都可)
# 確認是否氣密(重要)
#
# 或看影片學習(ref5
# 不要花了那麼多時間排隊
# 卻用錯方式來使用
#
#
# B. 預防接觸傳播：
#
# 其實大部分中招的人都是接觸傳染的
#
# 就算即使你24小時戴口罩(ref6
# 手東摸摸、西摳摳拿下又戴上
# 或者你在公車、捷運上摩肩擦踵
# 肢體衣物接觸後再摸到口鼻眼還是枉然
#
# 能避免的方式是濕洗手
# 正確口訣是內外夾弓大立腕
# 內：手心互相搓洗
# 外：手心搓洗手背
# 夾：十指交扣搓洗
# 弓：四指指內搓洗
# 大：旋轉搓洗拇指
# 立：五指尖洗手心
# 腕：清洗左右手腕(這步驟可不用)
#
# 即使被武漢肺炎內外夾攻
# 我們還是要大力的萬眾一心
#
#
# 影片有三個版本：
# 疾管屬(CDC)版本
# 感應式水龍頭無"腕"步驟(ref7
#
# 正妹護理許博士版
# 接觸式水龍頭有"腕"步驟(ref8
#
# 兒童巧虎老師版(ref9
#
#
# 擦乾時建議用烘手機或乾淨紙巾擦
# 公用的擦手巾會讓你白洗(病菌又回來了)
#
# 洗手時間需要30秒以上
# 做好這個步驟接觸(糞口)傳染就能有效預防
#
#
# 我能做的實在很有限
# 請大家多多跟自己家人親友
# 拜託教導正確的戴口罩、洗手步驟
# 或者稍微了解一下武漢肺炎細節(ref15
# 畢竟他們中招，下一個就離你各位不遠了
#
#
#
# 正片開始：藥局領口罩懶人包(ref10
#
#
# 1. "目前"只有藥局、衛生所才能買到公發口罩
#
# 疾管署公告：自2月16日(星期日)起(ref19
# 增加可以購買實名制口罩的303家衛生所
# 各地衛生所位置PDF轉圖片相冊(ref20
#
# 衛生所證件只接受健保卡或居留證
# 請大家前往時記得再確認領口罩時間
#
#
# 而藥局位置、數量可查口罩供需資訊平台(ref11
# 診所、醫院"目前"也不能買公發的
# 出發前請查詢該藥局的營業時間
# 領口罩時請問該藥局何時領會最方便
# 請注意平台顯示的口罩數量不一定正確
#
# 健保局有給我們每天兩小時發口罩時間
# 錯過的話藥局可以不處理口罩業務(註1
#
# 口罩管控系統(實名制平台)開機時間
# 目前明訂為每天的07:00-22:00
# 過早或太晚來也是無法發放口罩的
#
#
# 2. 每家藥局每日配額(ref12
#
# 每天有大人400個，小孩200個(ref22
# 郵差今天送的是明天要發的份量
# 禮拜天藥局可選擇不處理口罩業務(休息)
#
# 目前大人有收到三層(一般)、四層(活性碳)的
# 小孩有收到一般平面及立體印花口罩
# 詢問過皆為醫用口罩
#
# 但若收到你覺得哪裡怪怪的口罩
# 實在不放心請撥給食藥署確認(口罩歸他管)
#
#
# 3. 7天領一次口罩
#
# 原本只能各買1次2片
#
# 2/20開始
# 大人一次2片10元(不變)
#
# 小孩買小孩增量一次4片20元
# 小孩買大人維持一次2片10元(ref22
# 小孩買小孩或大人只能擇一不能混搭(ref23
#
#
# 假設你明天禮拜四(2/6)來買
# 最快是下周四(2/13)才可以買(+7天)
# 日期不到會鎖卡(跳異常)
# A店買完去B店也會
#
# 不能說我14天沒買這次買2倍量
# 也不能說我未來5年不買這次買200個
#
# 如果+7太困難計算
# 固定這次星期"幾"買
# 下周"幾"買就不會忘
#
# 目前7天內是看日期而不是看時間
# 假設2/6 20:00購買
# 2/13 任一時間就可以買
# 不用等到2/13 20:01才能買
#
# 如果你明明沒有買過
# 但購買處說買過且時間還沒到
# 請撥打1919，統一由健保署仲裁(ref21
#
#
# 4. 大人小孩口罩條件
#
# 13歲以下(96年後出生)可選大人或小孩
# 因為需要額外手動更改
# 如果該藥局不是很清楚流程
# 請"有禮貌"出示此操作流程圖(ref16
#
# 14歲以上只能買大人口罩
# 你是巴掌臉的大人就抱歉囉
#
#
# 5. 有無健保卡皆可領
#
# 有健保卡可以加速我們發口罩的流程
#
# 衛生所依公告(ref19
# 只接受健保卡或居留證
# 藥局依公告(ref10
# 可接受健保卡、居留證外
# 還可接受身分證、戶口名簿、出入境許可證
# (只需攜帶以上其中一個正本證件)
#
# 依照你上面的ID NO.(身分證)尾數分流購買
# 1, 3, 5, 7, 9，星期一、三、五可領
# 0, 2, 4, 6, 8，星期二、四、六可領
# 禮拜天，大家都可以領
# 號碼不對會鎖卡(跳異常)
#
#
# 6. 1人1次最多可以幫另1個人購買
#
# 就比如你要排5人(並符合尾數分流條件)
# 你一次排2個
# 領完再排2次就可以了
#
# 但細則是說本人可代領另1位
# 如果是這樣你可能要排4次喔
# 有禮貌的朋友我們應該不會互相刁難啦...
#
#
# 7. 口罩公差(志工)上線啦
#
# 藥師公會全聯會
# 於2/12 19:28發布(ref17
#
# 針對部分藥局反應人手不足部分
# 公會與地方民政局合作
#
# 今日先於台北市及嘉義縣進行試辦
# 民政局業已公告里長派志工於發放時協助
#
# 目前內政部業已同意
# 若效果不錯
# 未來各地比照辦理
#
#
# 如果你是台北市及嘉義縣的民眾
# 因為上班還是總總關係一直領不到
#
# 請有禮貌的聯繫你的里長(ref18
# 詢問下班時段是否有志工協助發放的地方
# (但我猜應該還是有很多里長不知道這件事)
#
# 若是口罩志工成效不錯
# 將來各縣市的上班族就有福了
#
#
# 大致上就以上了
#
#
# 2/4 全聯會發的文(ref13
#
# 無故不參與此次防疫之健保特約藥局
# 各縣市藥師及藥劑生公會
# 應實際瞭解後告知全聯會
#
# 若無正當理由
# 由全聯會建請健保署直接與藥局解約
#
# 我想很多對系統不熟的藥師
# (點收及發放口罩)
# 尤其是一人藥局是非常具有殺傷力的
# 請各位多擔待
#
#
# 2/5 的新聞(ref14
#
# 藥師公會全國聯合理事長黃金舜：
# 他給超商3元，超商是給消費者8元
# 我們跟民眾收到的，兩個口罩10元
# 10元我們收到以後，是全部交給國庫
#
# 跟你各位收到的10元
# 我們"可能"是100%上繳國庫
# 之前請各位準備乾淨的分裝袋
# 也怕其他地方的藥師沒準備包材
#
#
# 最後
# 藥局是易感染疾病的地方
# 排隊時要記得戴口罩
#
# 快輪到你時
# 先把10元和健保卡握在手上
# 這樣我們就會比較快
#
# 如果可以
# 請協助傳播正確戴口罩及洗手知識
#
# 愛你們喔！
# 大家加油！
#
#
# 註1. 2020 2/5 20:55 update
# 不少藥局是一人藥局或有其他業務
# 所以上頭說即使再忙也要分兩小時
# 用來處理口罩業務
#
# 看到目前有的同業是先發號碼牌
# 等到比較不忙的那兩小時再發口罩
#
# 不過如果大家都走這個流程
# 那口罩及時庫存查詢系統就廢了
#
# 因為看的到的及時庫存
# 早就用號碼牌的形式發光了
#
#
# ref1. http://bit.ly/37d9Ox3
# ref2. http://bit.ly/39mklYf
# ref3. http://bit.ly/31yywHg
# ref4. http://bit.ly/2uk3Ltv
# ref5. https://youtu.be/SiCpsI9bMxc
# ref6. https://youtu.be/KaOdoRpcFYY
# ref7. https://youtu.be/8wiBWkgZ3iI
# ref8. https://youtu.be/fg3SArRmYOI
# ref9. https://youtu.be/iK7QflCk2qg
# ref10. http://bit.ly/37f5sG4
# ref11. http://bit.ly/2UvOujX
# ref12. http://bit.ly/2vkJCTY
# ref13. http://bit.ly/2S9PWGV
# ref14. http://bit.ly/39jwsFO
# ref15. https://www.ptt.cc/bbs/nCoV2019/M.1580658113.A.AC5.html
# ref16. https://i.imgur.com/JY03AJz.jpg
# ref17. http://bit.ly/2uwDLey
# ref18. http://bit.ly/2vvFTmD
# ref19. http://bit.ly/31WgVsL
# ref20. http://bit.ly/37puP7T
# ref21. http://bit.ly/3bGKumT
# ref22. http://bit.ly/37IY9q6
# ref23. http://bit.ly/3272jqG
# ref24. http://bit.ly/38OYHfB
#
# -------------------

# %%
count = 0

artical_count = soup1.select('div [class="push"] [class="f3 push-content"]')
for count in range(0,len(artical_count)):
    commentContent = artical_count[count].text.replace(":","") 
    print(commentContent)
# Out:
#  加油！
#  辛苦了!
#  推
#  推
#  覺得除非完全沒有的人，不然開放第一周最好別去拿XD
#  太緊急上線了，可能實務會出很多小麻煩，而且領的人也多
#  推！
#  辛苦了
#  真的要講自備乾淨袋子，因為我相信那也是成本不是每個藥
#  局都有提供
#  我覺得從買了之後算這點不太好 一定開放前兩天通通擠過去
#  推
#  不然越晚買下次就要等越久 不是把量分散在七天內比較好?
#  我都自備「塑膠袋」去買口罩， 節省成本！
#  推
#  推推
#  有庫存的就不必去擠頭兩天
#  推
#  沒錯，頭兩天人最多， 可以晚點去
#  雖然實行前還是觀望，但是果然是類似比照慢簽或領藥
#  過卡異常這樣好控管，政策給推
#  推！詳細解說
#  訛啦 靴是要踹人嗎XD
#  家裡還有的人不用去跟急需要的人排！晚點去即可
#  推
#  推!!      是以訛傳訛啦 XDD
#  之前說依照身分證最後一碼，可是內文說依照健保卡號？
#  長網址...
#  推
#  今天看到有人從藥局出來拿一疊口罩（裸裝）
#  還好我親戚家開藥局
#  系統還沒上線，藥師也不熟悉，要限2小時賣完不然鎖系
#  統，啊你是有把握能限時處理完嗎？
#  推
#  沒有限兩個小時要賣完吧
#  推
#  哪裡有說限兩小時?
#  推
#  推！請大家多給工作人員一點鼓勵和耐心，少些責備。艱難時
#  刻，大家一起度過！
#   https//i.imgur.com/ah2xHmj.jpg
#  寫2小時口誤沒有鎖系統
#  推
#  推整理！
#  我記得全聯會說的兩小時是指應付客人的總工作時間推估
#  以250個口罩來看大約是應付一個人約需1分鐘
#  支持自己帶分裝袋減輕藥師負擔辛苦你們了？
#  啊啊啊是要打驚嘆號啦 辛苦了！
#  辛苦了每天照三餐打電話到公會問
#  推
#  幫第二個連結縮址 http//bit.ly/39aEAIE
#  口罩是分裝好了，但今晚下班前官方網頁連結都還沒弄好沒
#  推
#  電話來問很多，拜託明天不要太早來排隊
#  t大因有人發文插入推錯篇了,另兩句重要資訊建議補推,加油
#  推佛心藥師   可否尊稱您一稱藥師如來?
#  最後通知是明天早上9：00電腦才能連結
#  最可能的做法是明天先收健保卡算口罩數
#  滿了就結束，所以我錯了排隊還是有用
#  電視演出的是示範版，我們附近藥局都還連不上去，欄主是
#  不是也是這樣？明天早上只能先收卡再來領
#  有問過住家附近的藥局, 一間說1點開賣, 第二間說3點
#  開賣, 所以先跟藥局確認一下
#  推
#  大家都早上去先交健保卡 晚上下班的人就沒得買了
#   https//i.imgur.com/wITdTwk.jpg
#  已經開賣了賣得很好
#  分流一點時間也好
#  分配效果不錯
#  謝謝d大,t大,辛苦了
#  k大辛苦了
#  推
#  數量更新了
#  感謝 辛苦了！
#  都賣完了 中間小當 還算順利
#  政府效能人民素質不錯國家有希望
#  希望嚴格限制幫人代領也要自己可以領，不然阿桑每天拿兩
#  張家人朋友的健保卡去排隊就好了
#  樓上 政策是寫只能代領一人一卡
#  我是說 假設今天他領到了 也幫人代領 明天他能不能拿雙號
#  再幫人領一次
#  更正 單號
#  請問兒童口罩有醫療字號嗎?因為我查詢淨新這款查不到字
#  號
#  https//i.imgur.com/hN0m3uE.jpg
#  剛吃飯看到附近藥局 說1點開始 阿伯自己準備椅子應戰
#  感謝分享
#  如果限制代領也要自己可以領，跟小孩號數不同的家長怎麼
#  辦？像夫妻若都雙號、小孩的單號
#  帶著小孩去藥局領啊? 我只想到這個方法
#  辛苦了
#  辛苦藥局人員了
#  那個…可能沒辦法固定星期幾購買喔，規定是7天才能再買，
#  但實際上要8天才能買，因為有單雙號的問題
#  所以只有星期日買的才能固定
#  啊，抱歉弄錯了，是星期不是日期
#  請問有可能不搞號碼牌嗎 對上班族太難了
#  限制代領也要自己領，那行動不便但需要口罩去醫院的老人
#  怎麼辦？
#  覺得目前就也只能這樣了～
#  推
#  不發號碼牌，就得花更久時間，處理這部分。
#  不發號碼牌太強人所難了，有的藥局不大間耶
#  更別提人手有限
#  發號碼牌沒問題，問題是沒辦法即時反應庫存數，如果沒想出
#  辦法（例如藥局可以先在有條件下改庫存），系統真的廢了
#  感謝原po，超熱心，還幫忙詢問食藥署承辦同仁
#  如果有藥局只賣2小時口罩,超過時間即使有庫存,他也不賣
#  這樣要怎辦
#  反正都是看健保卡，除非你能生很多張
#  不然幫別人領，也沒辦法領太多
#  因為藥局賣口罩是幫忙, 他如果有庫存不賣,也沒約束力
#  可是口罩變成政府收回統一發,有些藥局又不太想配合
#  這是一個問題
#  有許可證即可
#  隔壁送一般口罩排了一公里 真的是服了
#  那群人了
#  覺得  明天會有領過的人搶號碼牌
#  買不到，唉
#  有領過的搶號碼牌 是代排？
#  發號碼牌亂象有點多，比預定時間提早發，導致有人要
#  代領但沒有對方的卡，藥局卻還是發2張號碼牌出去發(
#  這家晚上賣本來要圖利上班族，結果提早到還沒下班就
#  賣了)，結果後面排隊的人沒領到滿傻眼的
#  而且藥局領口罩是發活性碳?
#  有許可證即可
#  隔壁送一般口罩排了一公里 真的是服了
#  那群人了
#  覺得  明天會有領過的人搶號碼牌
#  買不到，唉
#  有領過的搶號碼牌 是代排？
#  號碼牌制度可不可以禁止啊…
#  發號碼牌比較不會趁亂插隊
#  開賣多時候店員忙售錢、發口罩，誰來盯
#  著人龍
#  開賣後沒立刻來領的話，庫存查詢還有什
#  麼用？
#  不覺得這種狀況比插隊好
#  嗎☎木可木可
#  有藥局酒精坐地起價,有通報嗎? 1950?
#  @樓上打1950通報無誤。公平法第40條
#  罰10萬~5千萬，不改善可處3年以下徒刑
#  我覺得不能隨到隨買太浪費人時間
#  星期一了 幹我單數號還是買不到
#  上禮拜五排了兩家沒 禮拜天還是沒
#  今天他媽的剛剛看到一家20多個的 到了
#  現場藥局說要號碼牌 死都不願賣兩個給我
#  幹早上發的號碼牌 我上班怎麼去排隊
#  下班去買 藥局明明有卻都要保留給號碼牌
#  鬼知道那些是誰領了號碼牌 卻到晚上了都
#  不去買的... 搞不好跟本就不是當天單數
#  號的人 真的是很機車 就等星期三了!!
#  星期三是單數號7天內的最後一天 如果再
#  買不到 那下一個7天循環又開始了 更買不
#  到了... 真的是很不爽 一堆藥店號碼牌
#  店裡明明就是有20幾個 就是不肯賣出來
#  想問一下，如果口罩改成由里長或鄰
#  長依戶口名簿來發放口罩及收取費用
#  這樣會不會比現在拿健保卡去藥局排
#  隊好？
#  不住在戶籍地的怎麼辦呢？
#  請問有人知道七天詳細是怎麼計算的嗎，
#  例如說週六下午三點買第一次，下週六也
#  一定要等到下午三點以後 才會滿7天 還是
#  只要到了下一個週六即使早上去買也會開
#  放 或是要算滿7天 變週日才能買下一次？
#  我已經放棄了 哈...
#  真的不行的上班民眾可請家人代領，認
#  卡不認人
#  買過的民眾要記得7+1天，買的當天不
#  算
#  5. 有無健保卡皆可領 補充一下：如果有
#  健保卡但沒帶不能領/未加保才可以身份
#  證戶口名簿領口罩
#  有人跟我一樣到現在還沒買到過的嗎...淚跑
#  了好幾家，打電話問了好幾家...上班族不可
#  能下午3點在那邊領號碼牌排隊啊！
#  我R
#  可以試試門前藥局喔，那種診所自己附設
#  的健保藥局，比較少人知道
#  要再推一下k大,線下線上都提供專業服務
#  請問”登記”實名制是不是會更有效率，
#  就像去超商取貨的方式，使用ID先上網登
#  記要去領取的藥局，這樣既知道總量，大
#  家也不用排隊領取，反正一定領的到
#  問題就在數量不多啊
#  藥局說沒接到明確通知12歲以下兒童可換大人款
#  ，說兒童只給換兒童的（白白排隊了…
#  k大先前提的衛生所買實名口罩實現了
#  https//yerl.org/o6VQl
#  2/16開賣,有全國名單,要準備編修V2.4了嗎
#  https//heho.com.tw/archives/69018
#  https//i.imgur.com/uolDq62.jpg
#  有給藥局看懶人包流程圖，可是她們堅持不手動
#  改，大概因為我後面還排很多人(？)
#  請問手動改會導致口罩販售庫存顯示不正確嗎？
#  推V2.4,不過我覺得k大可以考慮跟我一樣
#  標題是更新內容"新增303家衛生所領買口罩"
#  我看到衛生所了,當我眼瞎 XDDD
#  第一點衛生所的色碼上失敗了
#  酒精都欠貨
#  酒精不難買 台酒每天都有限購的貨量 要
#  早早去排隊就是了
#  請問藥局周日休息的話 星期一會連周日的
#  量一起賣嗎
#  感謝
#  現在台酒 95% 還要排隊嗎... 沒辦法
#  跟那些人一樣0700就去排隊搶
#  推k大真的很有耐心溫和地有問必答耶XD

# %%
soup1.select('div [class="push"]')
# Out:
# [<div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zold</span><span class="f3 push-content">: 加油！</span><span class="push-ipdatetime"> 02/05 16:57
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 辛苦了!</span><span class="push-ipdatetime"> 02/05 17:01
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">sad0soul</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:01
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">xhakiboo</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:02
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">snownow</span><span class="f3 push-content">: 覺得除非完全沒有的人，不然開放第一周最好別去拿XD</span><span class="push-ipdatetime"> 02/05 17:02
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">snownow</span><span class="f3 push-content">: 太緊急上線了，可能實務會出很多小麻煩，而且領的人也多</span><span class="push-ipdatetime"> 02/05 17:02
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">senstivewu</span><span class="f3 push-content">: 推！</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">aeoleron</span><span class="f3 push-content">: 辛苦了</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lonven</span><span class="f3 push-content">: 真的要講自備乾淨袋子，因為我相信那也是成本不是每個藥</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lonven</span><span class="f3 push-content">: 局都有提供</span><span class="push-ipdatetime"> 02/05 17:03
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">recx</span><span class="f3 push-content">: 我覺得從買了之後算這點不太好 一定開放前兩天通通擠過去</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">fishwan</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">recx</span><span class="f3 push-content">: 不然越晚買下次就要等越久 不是把量分散在七天內比較好?</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zold</span><span class="f3 push-content">: 我都自備「塑膠袋」去買口罩， 節省成本！</span><span class="push-ipdatetime"> 02/05 17:04
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Doralice</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:05
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">hwider</span><span class="f3 push-content">: 推推</span><span class="push-ipdatetime"> 02/05 17:05
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Doralice</span><span class="f3 push-content">: 有庫存的就不必去擠頭兩天</span><span class="push-ipdatetime"> 02/05 17:06
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">qqq5890003</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:08
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zold</span><span class="f3 push-content">: 沒錯，頭兩天人最多， 可以晚點去</span><span class="push-ipdatetime"> 02/05 17:10
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Baltokalin</span><span class="f3 push-content">: 雖然實行前還是觀望，但是果然是類似比照慢簽或領藥</span><span class="push-ipdatetime"> 02/05 17:10
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Baltokalin</span><span class="f3 push-content">: 過卡異常這樣好控管，政策給推</span><span class="push-ipdatetime"> 02/05 17:10
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">all0917</span><span class="f3 push-content">: 推！詳細解說</span><span class="push-ipdatetime"> 02/05 17:14
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ROCAF</span><span class="f3 push-content">: 訛啦 靴是要踹人嗎XD</span><span class="push-ipdatetime"> 02/05 17:15
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">happyLynn</span><span class="f3 push-content">: 家裡還有的人不用去跟急需要的人排！晚點去即可</span><span class="push-ipdatetime"> 02/05 17:16
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Juinsy</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:16
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jcamnos</span><span class="f3 push-content">: 推!!      是以訛傳訛啦 XDD</span><span class="push-ipdatetime"> 02/05 17:18
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">groo</span><span class="f3 push-content">: 之前說依照身分證最後一碼，可是內文說依照健保卡號？</span><span class="push-ipdatetime"> 02/05 17:19
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">laechan</span><span class="f3 push-content">: 長網址...</span><span class="push-ipdatetime"> 02/05 17:21
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tiyehpai</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:22
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">xj4bp6ejo3</span><span class="f3 push-content">: 今天看到有人從藥局出來拿一疊口罩（裸裝）</span><span class="push-ipdatetime"> 02/05 17:22
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">anguslf2</span><span class="f3 push-content">: 還好我親戚家開藥局</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lightwing</span><span class="f3 push-content">: 系統還沒上線，藥師也不熟悉，要限2小時賣完不然鎖系</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightwing</span><span class="f3 push-content">: 統，啊你是有把握能限時處理完嗎？</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">witcherysky</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:23
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">NCUking</span><span class="f3 push-content">: 沒有限兩個小時要賣完吧</span><span class="push-ipdatetime"> 02/05 17:25
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ThisIsNotKFC</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 02/05 17:26
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">
a></span><span class="push-ipdatetime">  103.10.197.98 02/15 15:46
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 2/16開賣,有全國名單,要準備編修V2.4了嗎</span><span class="push-ipdatetime">  103.10.197.98 02/15 15:48
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: <a href="https://heho.com.tw/archives/69018" rel="nofollow" target="_blank">https://heho.com.tw/archives/69018</a></span><span class="push-ipdatetime">  103.10.197.98 02/15 15:50
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: <a href="https://i.imgur.com/uolDq62.jpg" rel="nofollow" target="_blank">https://i.imgur.com/uolDq62.jpg</a></span><span class="push-ipdatetime">  103.10.197.98 02/15 15:51
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">XDa</span><span class="f3 push-content">: 有給藥局看懶人包流程圖，可是她們堅持不手動</span><span class="push-ipdatetime">   61.60.127.24 02/15 16:00
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">XDa</span><span class="f3 push-content">: 改，大概因為我後面還排很多人(？)</span><span class="push-ipdatetime">   61.60.127.24 02/15 16:05
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">XDa</span><span class="f3 push-content">: 請問手動改會導致口罩販售庫存顯示不正確嗎？</span><span class="push-ipdatetime">   61.60.127.24 02/15 16:16
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 推V2.4,不過我覺得k大可以考慮跟我一樣</span><span class="push-ipdatetime">  103.10.197.98 02/15 17:45
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 標題是更新內容"新增303家衛生所領買口罩"</span><span class="push-ipdatetime">  103.10.197.98 02/15 17:45
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 我看到衛生所了,當我眼瞎 XDDD</span><span class="push-ipdatetime">  103.10.197.98 02/15 17:46
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 第一點衛生所的色碼上失敗了</span><span class="push-ipdatetime">  103.10.197.98 02/15 18:01
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">neil3000</span><span class="f3 push-content">: 酒精都欠貨</span><span class="push-ipdatetime"> 220.141.117.56 02/15 21:54
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Angel2011</span><span class="f3 push-content">: 酒精不難買 台酒每天都有限購的貨量 要</span><span class="push-ipdatetime">   36.228.28.30 02/16 11:04
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Angel2011</span><span class="f3 push-content">: 早早去排隊就是了</span><span class="push-ipdatetime">   36.228.28.30 02/16 11:04
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">youknew</span><span class="f3 push-content">: 請問藥局周日休息的話 星期一會連周日的</span><span class="push-ipdatetime">125.227.138.223 02/18 09:58
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">youknew</span><span class="f3 push-content">: 量一起賣嗎</span><span class="push-ipdatetime">125.227.138.223 02/18 09:58
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lisalisa88</span><span class="f3 push-content">: 感謝</span><span class="push-ipdatetime">   106.1.225.15 02/19 01:44
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Yjizz</span><span class="f3 push-content">: 現在台酒 95% 還要排隊嗎... 沒辦法</span><span class="push-ipdatetime"> 49.215.204.224 02/20 04:17
#  </span></div>,
#  <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Yjizz</span><span class="f3 push-content">: 跟那些人一樣0700就去排隊搶</span><span class="push-ipdatetime"> 49.215.204.224 02/20 04:17
#  </span></div>,
#  <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ismail</span><span class="f3 push-content">: 推k大真的很有耐心溫和地有問必答耶XD</span><span class="push-ipdatetime"> 103.10.197.102 02/20 21:32
#  </span></div>]

# %%
print(canonicalUrl)
# Out:
# https://www.ptt.cc/bbs/nCoV2019/M.1580893040.A.BA5.html

# %%
#擷取頁數
allpageurl = soup.select('.btn.wide')[1]['href']
start_index = allpageurl.find('index')
end_index = allpageurl.find('.html')
page_number = int(allpageurl[start_index + 5 : end_index])+1
print(page_number)
# Out:
# 146

# %%
import time
import datetime
artical_count = soup1.select('div [class="push"] [class="push-ipdatetime"]')
for count in range(0,len(artical_count)):
    commentTime_tmp = artical_count[count].text.replace('\n','')[-11:]          #推文時間
    print(commentTime_tmp)
    commentTime_year = '{} '.format(time_year)+commentTime_tmp
    print(commentTime_year)   
    commentTime = time_mktime(commentTime_year)
    print(resTime)
# Out:
# 01/26 21:28
#  2020 01/26 21:28
# 1580335620
# 01/26 21:28
#  2020 01/26 21:28
# 1580335620
# 01/26 21:29
#  2020 01/26 21:29
# 1580335620
# 01/26 21:29
#  2020 01/26 21:29
# 1580335620
# 01/26 22:09
#  2020 01/26 22:09
# 1580335620
# 01/26 23:05
#  2020 01/26 23:05
# 1580335620
# 01/26 23:25
#  2020 01/26 23:25
# 1580335620
# 01/26 23:36
#  2020 01/26 23:36
# 1580335620
# 01/26 23:57
#  2020 01/26 23:57
# 1580335620
# 01/28 03:17
#  2020 01/28 03:17
# 1580335620
# 01/28 19:35
#  2020 01/28 19:35
# 1580335620
# 01/28 20:41
#  2020 01/28 20:41
# 1580335620
# 01/28 20:41
#  2020 01/28 20:41
# 1580335620
# 01/29 00:04
#  2020 01/29 00:04
# 1580335620
# 01/29 15:22
#  2020 01/29 15:22
# 1580335620
# 01/29 18:20
#  2020 01/29 18:20
# 1580335620
# 01/29 19:29
#  2020 01/29 19:29
# 1580335620
# 01/29 20:21
#  2020 01/29 20:21
# 1580335620
# 01/29 20:22
#  2020 01/29 20:22
# 1580335620
# 01/29 20:27
#  2020 01/29 20:27
# 1580335620
# 01/29 22:07
#  2020 01/29 22:07
# 1580335620
# 01/29 22:07
#  2020 01/29 22:07
# 1580335620
#
#  2020
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-3e1bb9a4bc80> in time_mktime(publishedTime)
#      14     try:
# ---> 15         resTime = str(round(time.mktime(time.strptime(publishedTime,'%a %b %d %H:%M:%S %Y')),))+"000"
#      16     except Exception:
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime_time(data_string, format)
#     570     format string."""
# --> 571     tt = _strptime(data_string, format)[0]
#     572     return time.struct_time(tt[:time._STRUCT_TM_ITEMS])
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
#
# ValueError: time data ' 2020 ' does not match format '%a %b %d %H:%M:%S %Y'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-1ff81fa6ffb1> in <module>
#       9     #resTime = str(round(time.mktime(time.strptime(commentTime_year,' %Y %m/%d %H:%M')),))
#      10
# ---> 11     commentTime = time_mktime(commentTime_year)
#      12     print(resTime)
#      13
#
# <ipython-input-139-3e1bb9a4bc80> in time_mktime(publishedTime)
#      15         resTime = str(round(time.mktime(time.strptime(publishedTime,'%a %b %d %H:%M:%S %Y')),))+"000"
#      16     except Exception:
# ---> 17         resTime = str(round(time.mktime(time.strptime(publishedTime,' %Y %m/%d %H:%M')),))
#      18     return resTime
#      19
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime_time(data_string, format)
#     569     """Return a time struct based on the input string and the
#     570     format string."""
# --> 571     tt = _strptime(data_string, format)[0]
#     572     return time.struct_time(tt[:time._STRUCT_TM_ITEMS])
#     573
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
#     361         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data ' 2020 ' does not match format ' %Y %m/%d %H:%M'

# %%
class_board = ['NBA','nCoV2019','joke','Gossiping']
for board in class_board:
    print(board)
# Out:
# NBA
# nCoV2019
# joke
# Gossiping

# %%
start_date_tmp = '2013-1-1'
start_date = last_mktime(start_date_tmp)
print(start_date)
end_date_tmp = '2020-1-1'
end_date = last_mktime(end_date_tmp)
print(end_date)

class_board = ['NBA']
def range_search(start_date,end_date,class_board): #抓設定範圍內的文章
    for board in class_board:
        page_number = allpage_number(board)
        for page_count in range(1,page_number):                                    #判斷每一頁的最後一篇文章
            url= 'https://www.ptt.cc/bbs/NBA/index{}.html'.format(page_count+1)
            print("第",page_count,"頁")
            res = requests.get(url,headers = headers, cookies = {'over18':'1'})    #請求分類看板首頁
            soup = BeautifulSoup(res.text, 'html.parser')
            last = soup.select('div [class="r-ent"] ')
            tmp_last = 'https://www.ptt.cc'+last[len(last)-1].a["href"]            #取出當前頁最後一篇文章網址
            print(tmp_last)
            try:
                res2 = requests.get(tmp_last,headers = headers, cookies = {'over18':'1'}) 
                soup2 = BeautifulSoup(res2.text, 'html.parser')
                time2 = soup2.select('span[class="article-meta-value"]')
                someTime_tmp2 = time2[3].text
                lastTime2 = time_mktime(someTime_tmp2)                     #當前頁面 最後一篇文章的貼文時間
                print("最後一篇貼文時間: "+lastTime2)
            except Exception :
                print('貼文時間關閉')

            if start_date <= lastTime2 :                                   #判斷每一頁的最後一篇文章的時間
                for compare_count in len(last):
                    compare_url = last[compare_count].a['href']            #取出第一篇文章的文章網址
                    res3 = requests.get(compare_url,headers = headers, cookies = {'over18':'1'})
                    soup3 = BeautifulSoup(res3.text, 'html.parser')
                    time3 = soup3.select('span[class="article-meta-value"]')
                    someTime_tmp3 = time3[3].text
                    lastTime3 = time_mktime(someTime_tmp3)                  #抓出第一篇文章時間
                    if lastTime3>=start_date and lastTime3 <= end_date     #第一篇文章時間大於起始時間就抓整頁文章
                        #20篇  #邊抓邊存 不要一次append完
                        title_url = soup3.select('div[class="title"] a')
                        for g,i in enumerate(title_url) :
                            try:
                                sort_tmp = i.text
                                sort = re.findall(r'\[\w\w',sort_tmp)[0].replace('[','')
                                print('文章分類為:'+ sort)                                     #文章分類
                            except Exception :
                                print('文章分類為: 其他')
                            try:
                                title = i.text.replace(' ','').split(']')[1]                  #文章標題
                                print(title)
                            except Exception :
                                title = i.text
                                print(title)
                            article_id = i['href'][16:26]+'000'                           #文章編號
                            canonicalUrl = 'https://www.ptt.cc'+i['href']                 #標準網址
                            #print(canonicalUrl)
                            autherID_tmp = soup.select('div[class="author"] ')            
                            autherID = autherID_tmp[g].text                               #作者編號
                            print('作者標號 : '+autherID)
                    else
                        
                        return                                             #抓完時間內的文章後跳出
            else:
                pass
# Out:
#   File "<ipython-input-351-f0d0d002bc04>", line 38
#     if lastTime3>=start_date and lastTime3 <= end_date     #第一篇文章時間大於起始時間就抓整頁文章
#                                                                                ^
# SyntaxError: invalid syntax

# %%
last[0]
# Out:
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1090693749.A.D48.html">[轉錄][我愛灰狼]灰狼愛我</a>
# </div>
# <div class="meta">
# <div class="author">shanyaochung</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%88%91%E6%84%9B%E7%81%B0%E7%8B%BC%5D%E7%81%B0%E7%8B%BC%E6%84%9B%E6%88%91">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ashanyaochung">搜尋看板內 shanyaochung 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/24</div>
# <div class="mark">M</div>
# </div>
# </div>

# %%
def last_mktime(start_date_tmp):
    import time
    resTime = str(round(time.mktime(time.strptime(start_date_tmp,'%Y-%m-%d')),))
    return resTime

start_date_tmp = '2020-1-1'
start_date = last_mktime(start_date_tmp)
print(start_date)
end_date_tmp = '2019-1-1'
end_date = last_mktime(end_date_tmp)
print(end_date)
# Out:
# 1577836800
# 1546300800

# %%
import pymysql
# 開啟資料庫連線
#db=pymysql.connect(host='mysql',user='root',passwd='123456',port=3306,charset='utf8')
db = pymysql.connect("mysql","root","123456","" )
# 使用 cursor() 方法建立一個遊標物件 cursor
cursor = db.cursor()
# 使用 execute()  方法執行 SQL 查詢 
cursor.execute("SELECT VERSION()")


# 使用 fetchone() 方法獲取單條資料.
data = cursor.fetchone()
print ("Database version : %s " % data)
# 關閉資料庫連線
db.close()
# Out:
# Database version : 8.0.19

# %%
updateTime_tmp11 = soup1.select('span[class="f2"]')
# try:
# updateTime = updateTime_tmp11[len(updateTime_tmp11)-1]
updateTime = updateTime_tmp11[3]
updateTime_convert = updateTime.text.replace('\n','').split(',')[1]
print(updateTime_convert[-13:-8])
updateTime_last = time_convert(updateTime_convert)
print('最後更新時間: '+updateTime_last)                     #更新時間
# except IndexError :
#     print('最後更新時間:沒有更新')
# Out:
# 2020
# 最後更新時間: 2020-02-24T10:44:26.020+00:00

# %%
updateTime
# Out:
# <span class="f2">:轉錄至看板 Wizards</span>

# %%
updateTime_tmp11[3]
# Out:
# <span class="f2">※ 編輯: Rambo (65.78.10.87 美國), 02/24/2020 10:44:26
# </span>

# %%
url_tmp = 'https://www.ptt.cc/bbs/NBA/index7.html'
resttt = requests.get(url_tmp,headers = headers, cookies = {'over18':'1'})
soupttt = BeautifulSoup(resttt.text, 'html.parser')

# %%
soupttt
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/NBA/index.html">看板</a>
# <a class="btn" href="/man/NBA/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/NBA/index6.html">‹ 上頁</a>
# <a class="btn wide" href="/bbs/NBA/index8.html">下頁 ›</a>
# <a class="btn wide" href="/bbs/NBA/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1088890954.A.256.html">Summer Leagues</a>
# </div>
# <div class="meta">
# <div class="author">McDaniel</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3ASummer+Leagues">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AMcDaniel">搜尋看板內 McDaniel 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/03</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1088894081.A.EBF.html">Top FA -- SF篇</a>
# </div>
# <div class="meta">
# <div class="author">Finley</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3ATop+FA+--+SF%E7%AF%87">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AFinley">搜尋看板內 Finley 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/03</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">5</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1089261407.A.24B.html">[MTSL] July 6</a>
# </div>
# <div class="meta">
# <div class="author">Parvati</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BMTSL%5D+July+6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AParvati">搜尋看板內 Parvati 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/08</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1089583579.A.069.html">Ginobili的步法</a>
# </div>
# <div class="meta">
# <div class="author">hreng</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3AGinobili%E7%9A%84%E6%AD%A5%E6%B3%95">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ahreng">搜尋看板內 hreng 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/11</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">15</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1089762364.A.97B.html">[討論] 高中球員和大學球員的比較??</a>
# </div>
# <div class="meta">
# <div class="author">CaTkinGG</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E9%AB%98%E4%B8%AD%E7%90%83%E5%93%A1%E5%92%8C%E5%A4%A7%E5%AD%B8%E7%90%83%E5%93%A1%E7%9A%84%E6%AF%94%E8%BC%83%3F%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ACaTkinGG">搜尋看板內 CaTkinGG 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/13</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1089813661.A.521.html">NBA／全聯盟最高薪還不爽　巴斯：祝福歐尼爾</a>
# </div>
# <div class="meta">
# <div class="author">Motola</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3ANBA%EF%BC%8F%E5%85%A8%E8%81%AF%E7%9B%9F%E6%9C%80%E9%AB%98%E8%96%AA%E9%82%84%E4%B8%8D%E7%88%BD%E3%80%80%E5%B7%B4%E6%96%AF%EF%BC%9A%E7%A5%9D%E7%A6%8F%E6%AD%90%E5%B0%BC%E7%88%BE">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3
div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%E6%9C%89%E9%97%9C%E7%81%B0%E7%8B%BC%E7%9A%84%E5%B9%BE%E5%80%8B%E7%B6%B2%E7%AB%99">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ajerod">搜尋看板內 jerod 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/24</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1090674729.A.606.html">[古董文章] 灰狼 GM Kevin McHale 傳 </a>
# </div>
# <div class="meta">
# <div class="author">DLowe</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%8F%A4%E8%91%A3%E6%96%87%E7%AB%A0%5D+%E7%81%B0%E7%8B%BC+GM+Kevin+McHale+%E5%82%B3+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ADLowe">搜尋看板內 DLowe 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/24</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1090693731.A.33A.html">[轉錄][我愛灰狼]我的灰狼史</a>
# </div>
# <div class="meta">
# <div class="author">shanyaochung</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%88%91%E6%84%9B%E7%81%B0%E7%8B%BC%5D%E6%88%91%E7%9A%84%E7%81%B0%E7%8B%BC%E5%8F%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ashanyaochung">搜尋看板內 shanyaochung 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/24</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1090693739.A.BEB.html">[轉錄][我愛灰狼]不再孤獨</a>
# </div>
# <div class="meta">
# <div class="author">shanyaochung</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%88%91%E6%84%9B%E7%81%B0%E7%8B%BC%5D%E4%B8%8D%E5%86%8D%E5%AD%A4%E7%8D%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ashanyaochung">搜尋看板內 shanyaochung 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/24</div>
# <div class="mark">M</div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
lastt = soupttt.select('div[class="title"] a')
try:
    title = lastt[compare_count].text.replace(' ','').split(']')[1]                  #文章標題
    print(title)
except Exception :
    title = i.text
    print(title)
article_id_tmp = lastt[compare_count]['href']                         #文章編號
end_index = article_id.find('.html')
article_id = article_id_tmp[9:end_index].replace(".","")
print(article_id)

canonicalUrl = 'https://www.ptt.cc'+lastt[compare_count]['href']                 #標準網址
canonicalUrl
# Out:
# 請問坎普的球迷
# M1090460741AB93
# 'https://www.ptt.cc/bbs/NBA/M.1090460741.A.B93.html'

# %%
lastt[compare_count]['href']
# Out:
# '/bbs/NBA/M.1090460741.A.B93.html'

# %%
a = ['11','22','33','44']
b = '33'
for aa in a:
    if b == aa :
        print("OK")
    else:
        print("GG")
# Out:
# GG
# GG
# OK
# GG

# %%
compare_url = 'https://www.ptt.cc/bbs/NBA/M.1105177436.A.47C.html'
res3 = requests.get(compare_url,headers = headers, cookies = {'over18':'1'})
soup_content = BeautifulSoup(res3.text, 'html.parser')
# try:
time3 = soup_content.select('span[class="article-meta-value"]')
someTime_tmp3 = time3[3].text
lastTime3 = compare_mktime(someTime_tmp3)                  #抓出第一篇文章時間
print('第一篇文章的時間'+lastTime3)
# except Exception:
#     lastTime3 = "0"
# Out:
# 第一篇文章的時間1105207275

# %%
a =['a','b','c','d']
b =['r','t','y','u']
a+b
# Out:
# ['a', 'b', 'c', 'd', 'r', 't', 'y', 'u']

# %%
start_date = 0
end_date = 0
start_date_tmp = '2004-7-1'                     #要抓的起始時間
start_date = last_mktime(start_date_tmp)
print(start_date)
end_date_tmp = '2004-7-10'                      #要抓的結束時間
end_date = last_mktime(end_date_tmp)
print(end_date)
class_board = ['NBA']                           
print('資料抓取完畢')
#如果沒有輸入起始時間跟結束時間就全抓
if start_date == 0 and end_date == 0
    class_board = ['NBA','nCoV2019','joke','Gossiping'] #可設定要抓哪幾個版
    all_board(class_board)
else:
    class_board = ['NBA']
    range_search(start_date,end_date,class_board)
